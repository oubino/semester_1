# %%
# when want to test on test data you have to write
# test_set.dataset.__test__() 
# which now means that all images loaded in (even ones from train & val would have no data augmentation)

# %%
# import libraries

import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import torchvision
import torchvision.transforms as transforms
import cv2
from PIL import Image, ImageOps
from sklearn.metrics import f1_score
from scipy import stats
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
from torchvision.models import AlexNet
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, datasets, models
from skimage import io, transform
import os
from torch.autograd import Variable

from collections import defaultdict
import torch.nn.functional as F
import torch
import torch.nn as nn
from __future__ import print_function

# %%
# import for visualisation of network

# !pip install graphviz
# !pip install torchviz
import graphviz
import torchviz

# !pip install kornia
import kornia 
from kornia import augmentation as aug
# Out:
# Requirement already satisfied: graphviz in c:\users\olive\anaconda3\lib\site-packages (0.15)
# Requirement already satisfied: torchviz in c:\users\olive\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: torch in c:\users\olive\anaconda3\lib\site-packages (from torchviz) (1.7.0)
# Requirement already satisfied: graphviz in c:\users\olive\anaconda3\lib\site-packages (from torchviz) (0.15)
# Requirement already satisfied: future in c:\users\olive\anaconda3\lib\site-packages (from torch->torchviz) (0.18.2)
# Requirement already satisfied: typing_extensions in c:\users\olive\anaconda3\lib\site-packages (from torch->torchviz) (3.7.4.2)
# Requirement already satisfied: dataclasses in c:\users\olive\anaconda3\lib\site-packages (from torch->torchviz) (0.6)
# Requirement already satisfied: numpy in c:\users\olive\anaconda3\lib\site-packages (from torch->torchviz) (1.18.5)
# Requirement already satisfied: kornia in c:\users\olive\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: torch>=1.6.0 in c:\users\olive\anaconda3\lib\site-packages (from kornia) (1.7.0)
# Requirement already satisfied: numpy in c:\users\olive\anaconda3\lib\site-packages (from kornia) (1.18.5)
# Requirement already satisfied: future in c:\users\olive\anaconda3\lib\site-packages (from torch>=1.6.0->kornia) (0.18.2)
# Requirement already satisfied: typing_extensions in c:\users\olive\anaconda3\lib\site-packages (from torch>=1.6.0->kornia) (3.7.4.2)
# Requirement already satisfied: dataclasses in c:\users\olive\anaconda3\lib\site-packages (from torch>=1.6.0->kornia) (0.6)

# %%
# use GPU

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device) # if on CUDA machine -> should print a CUDA device:
# !nvidia-smi  # tells you what GPU you're on
# Out:
# cuda:0
# Invalid combination of input arguments. Please run 'nvidia-smi -h' for help.

# %%
# global variables

# to specify landmark change 
# 1. landmarks array
# 2. ctr+f 'not general' -> bit in adam optimiser
# 3. change paths 

norm_mean = 180
norm_std = 180

batch_size = 1

landmarks = [3] # brainstem # not general
# sigmas = defaultdict(float) ?
sigmas = {} # sigma per landmark
for k in landmarks:
  sigmas[k] = nn.Parameter(torch.tensor([20.], device = 'cuda'))#.to(device) # what value to initialise sigma
  sigmas[k].requires_grad = True
  #print(sigmas[k])

num_class = len(landmarks)

# input dimensions
in_x = 128
in_y = 128
in_z = 80


# training parameters

epoch_num = 150

alpha = 1/25000
reg = 0.01 # reg = 0.001
gamma = 100000
lr_max = 0.1
lr_min = 0.0001
step_size = 64

threshold_img_print = 0.5

# normalise parameters
normal_min = 15
normal_max = 50
normal_window = 200

# mixed precision
use_amp = True

# %%
# change path to correct folder 



#from google.colab import drive
#drive.mount('/content/gdrive')
#PATH_OF_DATA= '/content/gdrive/"My Drive"/data/"HNSCC_deepmind_cropped"' # see content of dataset
#!ls {PATH_OF_DATA} # datasets.ImageFolder() expects data as root/label/picture.png
#root = '/content/gdrive/My Drive/data/HNSCC_deepmind_cropped' # note lack of " "


# if doing locally 

# computer

#from google.colab import drive
#drive.mount('/content/gdrive')
#PATH_OF_DATA = r'C:\Users\olive\OneDrive\Documents\CNN\3D_data\HNSCC_deepmind_cropped' # see content of dataset
#!ls {PATH_OF_DATA} # datasets.ImageFolder() expects data as root/label/picture.png
root = r'C:\Users\olive\OneDrive\Documents\CNN\3D_data\HNSCC_deepmind_cropped' # note lack of " "
import os
print(os.getcwd())
os.chdir(root)
print(os.getcwd())
# Out:
# C:\Users\olive\OneDrive\Documents\CNN\3D_data\HNSCC_deepmind_cropped
# C:\Users\olive\OneDrive\Documents\CNN\3D_data\HNSCC_deepmind_cropped

# %%
# custom dataset class for the images and masks

import cv2
import random
import sklearn
import skimage.transform as tr
import skimage
import scipy.ndimage


# CTDataset
class CTDataset(Dataset):
    """3D CT Scan dataset."""

    def __init__(self, root, transform_train =None, transform_test = None, test = False):
        """
        Args:
            root (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.root = root
        self.imgs = list(sorted(os.listdir(os.path.join(root, "CTs")))) # ensure they're aligned & index them
        self.structures = list(sorted(os.listdir(os.path.join(root, "Structures"))))
        # self.structure_centres = list(sorted(os.listdir(os.path.join(root, "Structure Centres"))))
        self.transform_train = transform_train
        self.transform_test = transform_test
        self.test = False
        
    def __getitem__(self, idx):
        if torch.is_tensor(idx): # convert tensor to list to index items
            idx = idx.tolist() 
        img_path = os.path.join(self.root, "CTs", self.imgs[idx]) # image path is combination of root and index 
        structure_path = os.path.join(self.root, "Structures", self.structures[idx])
        # structure_centre_path = os.path.join(self.root, "Structure Centres", self.structure_centres[idx])

        img = np.load(img_path) # image read in as numpy array
        structure = np.load(structure_path) # mask - think 0 = background
        # structure_centre = np.load(structure_centre_path)
        
        #print(img.shape)

        sample = {'image': img, 'structure': structure} # both are nd.arrays, stored in sample dataset

        if (self.transform_train) and (self.test == False):
            sample = self.transform_train(sample) # if transforms present, act on sample
        if (self.transform_test) and (self.test == True):
            sample = self.transform_test(sample) # if transforms present, act on sample
        
        sample['idx'] = idx
        
        if (structure.max() != structure.min()): # exclude images where no mask
          #print('mask_max:%5.2f, mask_min:%5.2f' % (mask.max(),mask.min()))
          #print('x where its equal to 1')
          #print((np.where(mask == mask.max())[0]))
          return sample 
        else:
          print('no structure?')
    
    def __len__(self):
        return len(self.imgs) # get size of dataset

    def __test__(self):
      self.test = True
    
    def __train__(self):
      self.train = False

#  -------- think this is redundant ---------
class DatasetFromSubset(Dataset):
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform

    def __getitem__(self, index):
        sample = self.subset[index]
        if self.transform:
            sample = self.transform(sample)
        return sample

    def __len__(self):
        return len(self.subset)

# --------------------------------------------

class Rescale(object): 
    # need to change rescale so longer side is matched to int and then pad
    """Rescale the image in a sample to a given size.

    Args:
        output_size (tuple or int): Desired output size. If tuple, output is
            matched to output_size. If int, smaller of image edges is matched
            to output_size keeping aspect ratio the same.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple)) # int keeps aspect ratio the same
        self.output_size = output_size

    def __call__(self, sample):
        # image, structure, structure_centre = sample['image'], sample['structure'], sample['structure_centre'] 
        image, structure = sample['image'], sample['structure']
        #print(mask.max())
        #print(mask.min())
        d, h, w = image.shape[:3] # define image height, width, depth as first 3 values

        
        if isinstance(self.output_size, int): # maintain aspect ratio so no loss of info
            if h > w:
                new_h, new_w = self.output_size * h / w, self.output_size
            else:
                new_h, new_w = self.output_size, self.output_size * w / h
        else:
            new_h, new_w = self.output_size
        new_h, new_w = int(new_h), int(new_w)
        
        # h and w are swapped for mask because for images,
        # x and y axes are axis 1 and 0 respectively
        img = transform.resize(image, (d, new_h, new_w),preserve_range = True, anti_aliasing = True) # anti-aliasing was false
        structure = transform.resize(structure, (d, new_h,new_w), preserve_range = True,  anti_aliasing = True) # anti-aliasing was false
        #mask_centre =  transform.resize(mask_centre, (new_h,new_w), preserve_range = True, anti_aliasing = True)
        #print(mask.max())
        #print(mask.min())

        return {'image': img, 'structure': structure}

class Normalise(object):  
  """ Normalise CT scan in the desired examination window
      takes in image as numpy """
  
  def __init__(self, level_min, level_max, window):
      self.level_min = level_min
      self.level_max = level_max
      self.window = window
                          
  def __call__(self, sample):
      image, structure = sample['image'], sample['structure']
      # need to normalise around different values
      level = random.randint(self.level_min, self.level_max)
      minval = max(level - self.window/2, 0) # ensures don't go to negative values
      maxval = level + self.window/2
      img_norm = np.clip(image, minval, maxval)
      img_norm -= minval
      img_norm /= self.window
      return {'image':img_norm, 'structure': structure} # note note !

class CentreCrop(object):    
  def __init__(self, depth, width, height):
      self.depth = depth
      self.width = width
      self.height = height
                          
  def __call__(self, sample):
      image, structure = sample['image'], sample['structure']

      d, h, w = image.shape[:3] # define image height, width, depth as first 3 values

      crop_w = (w - self.width) / 2  # 256 - new width(128)
      w_min = w / 4
      crop_h = (h - self.height) / 2
      crop_d = (d - self.depth) / 2
      d_min = crop_d / 4

      image = skimage.util.crop(image, ((0,0),(crop_w, crop_w), (crop_h, crop_h)))
      structure = skimage.util.crop(structure, ((0,0),(crop_w, crop_w),(crop_h,crop_h)))
      if self.depth < d:
        # crop
        crop_d = (d - self.depth) / 2
        
        image = skimage.util.crop(image,((crop_d,crop_d),(0,0),(0,0)))
        structure = skimage.util.crop(structure,((crop_d,crop_d),(0,0),(0,0)))

        new_d = image.shape[0]
        if new_d < self.depth:
          image = skimage.util.pad(image,((0,1),(0,0),(0,0)))
          structure = skimage.util.pad(structure,((0,1),(0,0),(0,0)))
        if new_d > self.depth:
          image = skimage.util.crop(image,((0,1),(0,0),(0,0)))
          structure = skimage.util.crop(structure,((0,1),(0,0),(0,0)))
      
      if self.depth > d:
        # pad
        pad_value = self.depth - d
        image = skimage.util.pad(image,((0,pad_value),(0,0),(0,0)))
        structure = skimage.util.pad(structure,((0,pad_value),(0,0),(0,0)))  

      d, h, w = image.shape[:3] # define image height, width, depth as first 3 values

      return {'image':image, 'structure': structure} # note note !

    
    


class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, sample):
        image, structure = sample['image'], sample['structure']
        # swap color axis because
        # numpy image: D x H x W 
        # torch image: C X H X W x D
        image = image.transpose(1,2,0)
        structure = structure.transpose(1,2,0)
        image = torch.from_numpy(image).float() # dont know why images/mask casted to float here but need to do it again later
        structure = torch.from_numpy(structure).float()
        structure = structure.unsqueeze(0) # force mask to have extra dimension i.e. (1xHxWxD)
        image = image.unsqueeze(0)
        return {'image': image,'structure': structure}

class Flips(object):

    def __call__(self, sample):
      image, structure = sample['image'], sample['structure']
      if random.random() <= 0.5:
        flip = transforms.Compose([aug.RandomHorizontalFlip3D(p=1, same_on_batch= True)])
        image = flip(image)
        structure = flip(structure)
      return {'image': image, 'structure': structure}

class Flips_scipy(object):
    def __call__(self,sample):
        image, structure = sample['image'], sample['structure']
        random_number = random.random()
        angle = random.randint(-10, 10)
        if random_number <= 0.33:
            image = scipy.ndimage.rotate(image, angle, axes = [1,0],reshape = False, order = 0)
            structure = scipy.ndimage.rotate(structure, angle, axes = [1,0], reshape = False, order = 0)
        if (random_number > 0.33) and (random_number <= 0.66):
            image = scipy.ndimage.rotate(image, angle, axes = [1,2], reshape = False, order = 0)
            structure = scipy.ndimage.rotate(structure, angle, axes = [1,2], reshape = False, order = 0)
        else:
            image = scipy.ndimage.rotate(image, angle, axes = [2,0], reshape = False, order = 0)
            structure = scipy.ndimage.rotate(structure, angle, axes = [2,0], reshape = False, order = 0)
        return {'image': image, 'structure': structure}
    
class Horizontal_flip(object):
    def __call__(self,sample):
        image, structure = sample['image'], sample['structure']
        random_number = random.random()
        if random_number <= 0.5:
            #print('image shape', image.shape)
            image = np.flip(image, axis = 2).copy()
            structure = np.flip(structure, axis = 2).copy()
            #print('horizontal flipped')
        return {'image': image, 'structure': structure}
       
    
class Upsidedown_scipy(object):
    def __call__(self,sample):
        image, structure = sample['image'], sample['structure']
        # if upside down need to flip
        # if left cochlea landmark = 5 above 1/2
        # data is y, x, z
        landmark_loc = np.where(structure == 5)
        if landmark_loc[0].size == 0: # if no 5 present check for 6
            landmark_loc = np.where(structure == 6)
            if landmark_loc[0].size == 0: # no 5 or 6 present just return image and structure
                return {'image': image, 'structure': structure}
            else:
                z_landmark = landmark_loc[0][0]
                z_size = structure.shape[0] 
                if z_landmark < z_size/2:
                    angle = 180
                    image = scipy.ndimage.rotate(image, angle, axes = [2,0], reshape = False, order =0)
                    #rotate(input, angle, axes=1, 0, reshape=True, output=None, order=3, mode='constant', cval=0.0, prefilter=True)
                    structure = scipy.ndimage.rotate(structure, angle, axes = [2,0], reshape = False, order =0)
                    return {'image': image, 'structure': structure}
                else:
                    return {'image': image, 'structure': structure}
                    
        else:
            z_landmark = landmark_loc[0][0]
            z_size = structure.shape[0] 
            if z_landmark < z_size/2:
                angle = 180
                image = scipy.ndimage.rotate(image, angle, axes = [2,0],reshape = False, order =0)
                #rotate(input, angle, axes=1, 0, reshape=True, output=None, order=3, mode='constant', cval=0.0, prefilter=True)
                structure = scipy.ndimage.rotate(structure, angle, axes = [2,0], reshape = False, order =0)
                return {'image': image, 'structure': structure}
            else:
                return {'image': image, 'structure': structure}
        
    
class Upsidedown(object):
  def __call__(self,sample):
    image, structure = sample['image'], sample['structure']
    # if upside down need to flip
    # if left cochlea landmark = 5 above 1/2
    # note that cause kornea takes in z, y, x between pre and post tranpose
    # data is z, y, x
    # com structure takes in y, x, z -> x, y, z
    # therefore if take in z, y, x -> y, z, x (*1)
    structure_com = com_structure(structure.unsqueeze(0), 5)
    structure_com_z = structure_com[0][0][1] # see (*1)
    z_size = structure.size()[1] # cause in this section is z, y, x
    #print(structure_com_z, z_size/2)
    if structure_com_z < z_size/2:
      flip = transforms.Compose([aug.RandomVerticalFlip3D(p=1)])
      image = flip(image)
      structure = flip(structure)
    #structure = torch.squeeze(structure,0)
    return {'image': image, 'structure': structure}

class Unsqueeze(object):
  def __call__(self,sample):
    image, structure = sample['image'], sample['structure']
    image = image.unsqueeze(0)
    structure = structure.unsqueeze(0)
    return {'image': image, 'structure': structure}




# for now not going to use below because not sure if it acts on image and structure equally
class Affine(object):
  def __call__(self, sample):
    image, structure = sample['image'], sample['structure']
    if random.random() <= 0.3:
      affine = transforms.Compose([aug.RandomAffine3D(degrees=(0,10,10), translate=(0,0.05,0.05), same_on_batch=True, p=1)])
      image = affine(image)
      print('affined')
      structure = affine(structure)


    return{'image': image, 'structure': structure}

class Noise(object):  # helps prevent overfitting
  #Random noise images
  def __call__(self,sample):
    image, structure = sample['image'], sample['structure']
    if random.random() <= 1:
      noise = transforms.Compose(aug.RandomMotionBlur3D(5, 10, direction=0, p=1))
      image = noise(image)
    return {'image': image, 'structure': structure}
class Noise1(object):  # helps prevent overfitting
 # Random noise images
  def __call__(self,sample):
    image, structure= sample['image'], sample['structure']
    if random.random() <= 1:
      image = skimage.util.random_noise(image, mean = 0, var = 1.0000000001, clip = False)
      # would this work given that mask is unchanged??
    return {'image': image, 'structure': structure}
class Pre_Transpose(object):
  def __call__(self, sample):
    image, structure = sample['image'], sample['structure']
    image = torch.transpose(image, 1, 3)
    image = torch.transpose(image, 2, 3)
    structure = torch.transpose(structure, 1, 3)
    structure = torch.transpose(structure, 2, 3)

    return {'image': image, 'structure': structure}

class Post_Transpose(object):
  def __call__(self, sample):
    image, structure = sample['image'], sample['structure']
    #torch.squeeze(image, 0)
    #torch.squeeze(structure, 0)

    structure = torch.squeeze(structure,0)
    image = torch.squeeze(image, 0)
    #torch.squeeze(structure,0)
    #torch.squeeze(image, 0)
    image = torch.transpose(image, 3, 2)
    image = torch.transpose(image, 3, 1)
    structure = torch.transpose(structure, 3, 2)
    structure = torch.transpose(structure, 3, 1)

    return {'image': image, 'structure': structure}
'''
class Squeeze(object):
  def __call__(self, sample):
    image, structure = sample['image'], sample['structure']
    image = torch.squeeze(image, 0)
    print('squeeze')
    structure = torch.squeeze(structure, 0)
    return {'image': image, 'structure': structure}
'''
# Out:
# "\nclass Squeeze(object):\n  def __call__(self, sample):\n    image, structure = sample['image'], sample['structure']\n    image = torch.squeeze(image, 0)\n    print('squeeze')\n    structure = torch.squeeze(structure, 0)\n    return {'image': image, 'structure': structure}\n"

# %%
# functions

def com_structure(heatmap, landmark): # assumes 1 channel
  # heatmap is batch of either masks or image of 
  # heatmap dim is (B x C x H x W x D)
  # output is (B x coord)
  # i.e. x,y,z of 3rd image = coords[3][0],coords[3coo][1], coords[3][2] only 1 channel
  batch_size = (heatmap.size()[0])
  landmark_present = []
  landmark = float(landmark) # ensure that comparison is made properly
  for i in range(batch_size):
    # heatmap shape [1, 1, 256, 256, 100] i.e. B x C x H x W x D
    locations = (heatmap[i][0] == landmark).nonzero().to(device)
    if (locations.size(0) == 0): # if no landmarks detected for image in batch
      print('no structure for %1.0f' % landmark)
      print('heatmap maximum value %5.2f' % heatmap[i][0].max())
      print('heatmap minimum value %5.2f' % heatmap[i][0].min())
      landmark_present.append(False)
      x_com = torch.tensor(0, dtype = torch.float64).to(device) # in theory this should not be used
      y_com = torch.tensor(0, dtype = torch.float64).to(device)
      z_com = torch.tensor(0, dtype = torch.float64).to(device)
    else:
      landmark_present.append(True)
      x_com = torch.tensor(0, dtype = torch.float64).to(device)
      y_com = torch.tensor(0, dtype = torch.float64).to(device)
      z_com = torch.tensor(0, dtype = torch.float64).to(device)
      for k in range(locations.size(0)): # number of landmarks
        x_com += locations[k][1]
        y_com += locations[k][0]
        z_com += locations[k][2]
      x_com /= locations.size(0)
      y_com /= locations.size(0)
      z_com /= locations.size(0)

    if i == 0:
      coords = torch.tensor([[x_com,y_com,z_com]]).to(device)
    else: 
      coords_temp = torch.tensor([[x_com,y_com,z_com]]).to(device)
      coords = torch.cat((coords,coords_temp),dim = 0)
  # returns arrays of B x coord
  # returns array of B x True/False
  # if True then for that coord it is COM, if false then need to produce heatmap of zeros
  return coords, landmark_present   

def top_structure(heatmap, landmark): # assumes 1 channel
  # heatmap is batch of either masks or image of 
  # heatmap dim is (B x C x H x W x D)
  # output is (B x coord)
  # i.e. x,y,z of 3rd image = coords[3][0],coords[3][1], coords[3][2] only 1 channel
  batch_size = (heatmap.size()[0])
  landmark_present = []
  landmark = float(landmark) # ensure that comparison is made properly
  for i in range(batch_size):
    # heatmap shape [1, 1, 256, 256, 100] i.e. B x C x H x W x D
    locations = (heatmap[i][0] == landmark).nonzero().to(device)
    if (locations.size(0) == 0): # if no landmarks detected for image in batch
      print('no structure for %1.0f' % landmark)
      print('heatmap maximum value %5.2f' % heatmap[i][0].max())
      print('heatmap minimum value %5.2f' % heatmap[i][0].min())
      landmark_present.append(False)
      x_top = torch.tensor(0, dtype = torch.float64).to(device) # in theory this should not be used
      y_top = torch.tensor(0, dtype = torch.float64).to(device)
      z_top = torch.tensor(0, dtype = torch.float64).to(device)
    else:
      landmark_present.append(True)
      x_top = torch.tensor(0, dtype = torch.float64).to(device)
      y_top = torch.tensor(0, dtype = torch.float64).to(device)
      z_top = torch.tensor(0, dtype = torch.float64).to(device)
      for k in range(locations.size(0)): # number of landmarks present in the image i.e. number of 3s in image
        # assumes image right way up 
        if (locations[k][2] > z_top): 
            x_top = locations[k][1]
            y_top = locations[k][0]
            z_top = locations[k][2]
    if i == 0:
      coords = torch.tensor([[x_top,y_top,z_top]]).to(device)
    else: 
      coords_temp = torch.tensor([[x_top,y_top,z_top]]).to(device)
      coords = torch.cat((coords,coords_temp),dim = 0)
  # returns arrays of B x coord
  # returns array of B x True/False
  # if True then for that coord it is TOP, if false then need to produce heatmap of zeros
  return coords, landmark_present  

def landmarks_coords(heatmap, landmark):
  # heatmap is batch of either masks or image of 
  # heatmap dim is (B x C x H x W x D)
  # output is (B x coords)
  # i.e. first (x,y,z) of 3rd image = coords[3][0]
  # i.e. second (x,y,z) of 3rd image = coords[3][1]
  batch_size = (heatmap.size()[0])
  landmark_present = []
  landmark = float(landmark) # ensure that comparison is made properly
  for i in range(batch_size):
    locations = (heatmap[i][0] == landmark).nonzero()
    if (locations.size(0) == 0): # if no landmarks detected for image in batch
      print('no structure for %1.0f' % landmark)
      print('heatmap maximum value %5.2f' % heatmap[i][0].max())
      landmark_present.append(False)
      x_com = torch.tensor(0, dtype = torch.float64).to(device) # in theory this should not be used
      y_com = torch.tensor(0, dtype = torch.float64).to(device)
      z_com = torch.tensor(0, dtype = torch.float64).to(device)
    else:
      landmark_present.append(True)
      # --- rewrite ---
      locations = locations.transpose(1,0,2) # not sure if this will work but need to change so have x,y,z
      if i == 0:
        coords = torch.tensor(locations).to(device) # coords should be array type object of x,y,z for each i (== image)
      else:
        coords_temp = torch.tensor(locations).to(device)
        coords = torch.cat((coords,coords_temp),dim = 0) # coords by the end will be B x coords_array_per_image
  # returns array of B x True/False
  # if True then has x,y,z of all posn of that landmark, if False then need to produce heatmap of zeros
  return coords, landmark_present   


from scipy import optimize
from scipy.optimize import curve_fit

# takes in heatmap of B x C x H x W x D
# i.e. batch x 6 channels x H x W x D
# needs to workout max (x,y,z) for specified landmark
def pred_max(heatmap, landmark): 
  a = torch.max(heatmap, dim = 4, keepdim = True)
  b = torch.max(a[0],dim =3,keepdim = True)
  c = torch.max(b[0],dim = 2,keepdim = True)
  batch_size = (heatmap.size()[0])
  for i in range(batch_size):
    index = landmarks.index(landmark)
    y = c[1][i][index][0][0][0]
    x = b[1][i][index][y][0][0]
    z = a[1][i][index][y][x][0]
    if i == 0:
      coords = torch.tensor([[x,y,z]]).to(device)
    else: 
      coords_temp = torch.tensor([[x,y,z]]).to(device)
      coords = torch.cat((coords,coords_temp),dim = 0)

  return coords   

# pred max gives maximum for each z layer between certain range of z 

def gauss_max(heatmap, landmark, height_trained, sigma_trained): # this should be current sigma for landmark
    # heatmap is batch of masks or images of dim (B x C x H x W x D)
    # output is (B x coord)
    # i.e. x,y of 3rd image = coords[3][0], coords[3][1] only 1 channel
    pred_coords = pred_max(heatmap, landmark).cpu().numpy()
    batch_size = (heatmap.size()[0])
    heatmap = heatmap.detach().cpu().numpy()
    index = landmarks.index(landmark)
    for i in range(batch_size):
        t = np.indices((in_y,in_x,in_z)).astype(float)  ## will be ~100,256,256 in your case
        def f(t, mu_i, mu_j, mu_k, height, sigma):                 ## function to be fitted
            pos = np.array([mu_i, mu_j, mu_k])      ## central position of the gaussian peak (using initial estimate of the argmax)
            t = t.reshape((3,in_y,in_x,in_z))           ## will be ~100,256,256 in your case
            dist_map = np.sqrt(np.sum([np.power((t[0] - pos[0]), 2), np.power((t[1] - pos[1]), 2), np.power((in_y/in_z * (t[2] - pos[2])), 2)], axis=0))  ## generate euclidean distance map to sample gauss fn on
            gauss = height * np.exp( - dist_map/ (2.*sigma*sigma) )
            return np.array(gauss, dtype=float).ravel()  ## generate gaussian using the estimated central point (your gauss scale will be different here too)
        #argmax_pred = np.unravel_index(torch.argmax(model_output[0]), model_output.size()[2:])  ## get initial guess of gauss peak (prediction argmax)
        #optimum_pos = curve_fit(f, t.ravel(), model_output[0].numpy().ravel(), p0=argmax_pred) ## optimisation process, compare predicted heatmap with generated gaussians (centre point shifted around to optimum)
        p0 = [pred_coords[i][0], pred_coords[i][1],pred_coords[i][2], height_trained, sigma_trained]
        
        # catch error
        try:
            params = curve_fit(f, t.ravel() , heatmap[i][index].ravel(), p0 = p0)          
            x = params[0][1]
            y = params[0][0]
            z = params[0][2]  

        except RuntimeError:
            print("Error - curve_fit failed")
            x = torch.tensor(0) # change !!!
            y = torch.tensor(0)
            z = torch.tensor(0)
        
        #print(params[0])
        #print(params[1])
        #print(params[2])
        

        x_max = heatmap.shape[3]
        y_max = heatmap.shape[2]
        z_max = heatmap.shape[4]
        x = max(0,min(x,x_max)) # keep x & y in [0,224]
        y = max(0,min(y,y_max))
        z = max(0,min(z,z_max))
        if i == 0:
            coords = torch.tensor([[x,y,z]])
        else: 
            coords_temp = torch.tensor([[x,y,z]])
            coords = torch.cat((coords,coords_temp),dim = 0)
        
    return coords

# %%
# dataloaders

trans_plain = transforms.Compose([Normalise(normal_min, normal_max, normal_window), CentreCrop(in_z,in_x,in_y), Upsidedown_scipy(), ToTensor()])
trans_augment = transforms.Compose([Normalise(normal_min, normal_max, normal_window),CentreCrop(in_z,in_x,in_y), Upsidedown_scipy(), Flips_scipy(), Horizontal_flip(),ToTensor()])
#trans_plain = transforms.Compose([Normalise(normal_min, normal_max, normal_window), Depth(100,256,256), Upsidedown_scipy(), ToTensor()])
#trans_augment = transforms.Compose([Normalise(normal_min, normal_max, normal_window),Depth(100,256,256), Upsidedown_scipy(), Flips_scipy(), ToTensor()])#, Pre_Transpose(), Check_com_present('bob'), Post_Transpose()])#,  Upsidedown(),Flips(), CentreCrop(), Affine(), Post_Transpose()])#HorizontalFlip()Noise(),, Affine() CentreCrop()CentreCrop(), Flips(), Affine(),
# torch image: C X H X W x D -> this is output and what we deal with from now on
# Upsidedown(), Flips(), CentreCrop(), Affine()

dataset = CTDataset(root, transform_train = trans_augment, transform_test = trans_plain, test = False )

# split data in train/val/test
train_size = int(0.8 * len(dataset))
val_size = int(0.1 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_set, val_set, test_set = torch.utils.data.random_split(dataset, [train_size, val_size, test_size], generator=torch.Generator().manual_seed(0))
# manual seed ensures that same split everytime to ensure testing on correct dataset!
# i.e. if random split, train, save, random split, test -> may end up testing on same as training!


image_datasets = {
    'train': train_set, 'val': val_set, 'test':test_set
}

# Load data in
dataloaders = {
    'train': DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=0),
    'val': DataLoader(val_set, batch_size=batch_size, shuffle=True, num_workers=0),
    'test': DataLoader(test_set,batch_size = batch_size, shuffle = False, num_workers=0)
}

# check dataloaders working
#print(train_set.__getitem__(0)['image'].size()) # i.e. 1 x 224 x 224 as torch tensor (C x H x W)
#print(train_set.__getitem__(0)['structure'].size()) 


for i in range(1):
    print(train_set.__getitem__(i)['structure'].size()) # i.e. 1 x 224 x 224 as torch tensor (C x H x W)
    for l in landmarks:
        print(com_structure(train_set.__getitem__(i)['structure'].unsqueeze(0), l))
    print('for image %1.0f' % i)
    #print(train_set.__getitem__(i)['structure'].size()) 


#img = dataset.__getitem__(10)['image']
#idx = dataset.__getitem__(10)['idx']
#print(idx)
# Out:
# torch.Size([1, 128, 128, 80])
# (tensor([[60.4610, 47.8300, 67.9336]], device='cuda:0', dtype=torch.float64), [True])
# for image 0

# %%
# gradient accumulation
# batch accumulation needs to be equal to the batch number will end on i.e. batch size 10, 73 images
# batch accumulation = 8
import math
batch_accumulation = math.ceil(train_set.__len__()/batch_size) # rounds it up

# %%
# plot 2D slice



image = train_set.__getitem__(0)['image']
structure = train_set.__getitem__(0)['structure']

print(structure.max())

img = image.numpy().squeeze(0)
structure = structure.numpy().squeeze(0)

print(img.shape)
plt.figure()
img = img[:, :, 50]
structure = structure[:, :, 50]

plt.imshow(img,cmap = 'Greys_r', alpha = 0.5)

# define the colors
cmap = matplotlib.colors.ListedColormap(['0','r', 'k','b','g','y','m'])

# create a normalize object the describes the limits of
# each color
bounds = [0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5]
norm = matplotlib.colors.BoundaryNorm(bounds, cmap.N)


# plot it
plt.imshow(structure, cmap = cmap, norm = norm, alpha = 0.5 )
plt.show()
# Out:
# tensor(6.)
# (128, 128, 80)

# %%
# plot 3D

import scipy.ndimage
import matplotlib.pyplot as plt
from skimage import measure, morphology
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
from mpl_toolkits.mplot3d import axes3d



#print(matplotlib.rcsetup.all_backends)
#matplotlib.use('TkAgg',warn=False, force=True)
# %matplotlib inline
matplotlib.pyplot.ion()


"""
def plot_3d(image, structure, threshold_img, threshold_structure):
    
    # Position the scan upright, 
    # so the head of the patient would be at the top facing the camera
    #p = image.transpose(2,1,0)
    print(train_set.__getitem__(0)['image'].size())
    
    verts_img, faces_img = measure.marching_cubes_classic(image, threshold_img)
    structure = extract_landmark_for_structure(structure, 3)
    verts_structure, faces_structure = measure.marching_cubes_classic(structure)#, threshold_structure)

    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')

    # Fancy indexing: `verts[faces]` to generate a collection of triangles
    mesh_img = Poly3DCollection(verts_img[faces_img], alpha=0.1)
    mesh_structure = Poly3DCollection(verts_structure[faces_structure], alpha=0.6)
    #face_color_img = [0.5, 0.5, 1]
    face_color_img = ['tab:gray']
    mesh_img.set_facecolor(face_color_img)
    #face_color_structure = ['r', 'b', 'g']
    face_color_structure = ['tab:red']
    mesh_structure.set_facecolor(face_color_structure)
    ax.add_collection3d(mesh_img)
    ax.add_collection3d(mesh_structure)

    ax.set_xlim(0, image.shape[1])
    ax.set_ylim(0, image.shape[0])
    ax.set_zlim(0, image.shape[2])

    ax.invert_xaxis()

    # rotate the axes and update
    ax.mouse_init(rotate_btn=1, zoom_btn=3)

    plt.show()

image_3d = train_set.__getitem__(0)['image']
print(image_3d.type)
image_3d = image_3d.squeeze(0)
image_3d = image_3d.numpy()

max_value = np.max(image_3d)
print(max_value)

structure_3d = train_set.__getitem__(0)['structure']
structure_3d = structure_3d.squeeze(0)
structure_3d = structure_3d.numpy()

for l in landmarks:
    print(com_structure(train_set.__getitem__(0)['structure'].unsqueeze(0), l))

plot_3d(image_3d,structure_3d,max_value/2, 6)

"""
# Out:
# "\ndef plot_3d(image, structure, threshold_img, threshold_structure):\n    \n    # Position the scan upright, \n    # so the head of the patient would be at the top facing the camera\n    #p = image.transpose(2,1,0)\n    print(train_set.__getitem__(0)['image'].size())\n    \n    verts_img, faces_img = measure.marching_cubes_classic(image, threshold_img)\n    structure = extract_landmark_for_structure(structure, 3)\n    verts_structure, faces_structure = measure.marching_cubes_classic(structure)#, threshold_structure)\n\n    fig = plt.figure(figsize=(10, 10))\n    ax = fig.add_subplot(111, projection='3d')\n\n    # Fancy indexing: `verts[faces]` to generate a collection of triangles\n    mesh_img = Poly3DCollection(verts_img[faces_img], alpha=0.1)\n    mesh_structure = Poly3DCollection(verts_structure[faces_structure], alpha=0.6)\n    #face_color_img = [0.5, 0.5, 1]\n    face_color_img = ['tab:gray']\n    mesh_img.set_facecolor(face_color_img)\n    #face_color_structure = ['r', 'b', 'g']\n    face_color_structure = ['tab:red']\n    mesh_structure.set_facecolor(face_color_structure)\n    ax.add_collection3d(mesh_img)\n    ax.add_collection3d(mesh_structure)\n\n    ax.set_xlim(0, image.shape[1])\n    ax.set_ylim(0, image.shape[0])\n    ax.set_zlim(0, image.shape[2])\n\n    ax.invert_xaxis()\n\n    # rotate the axes and update\n    ax.mouse_init(rotate_btn=1, zoom_btn=3)\n\n    plt.show()\n\nimage_3d = train_set.__getitem__(0)['image']\nprint(image_3d.type)\nimage_3d = image_3d.squeeze(0)\nimage_3d = image_3d.numpy()\n\nmax_value = np.max(image_3d)\nprint(max_value)\n\nstructure_3d = train_set.__getitem__(0)['structure']\nstructure_3d = structure_3d.squeeze(0)\nstructure_3d = structure_3d.numpy()\n\nfor l in landmarks:\n    print(com_structure(train_set.__getitem__(0)['structure'].unsqueeze(0), l))\n\nplot_3d(image_3d,structure_3d,max_value/2, 6)\n\n"

# %%
# network

import torch
from torch import nn
import torch.nn.functional as F

# UNET3D

unet_feat = 4

class ConvUnit(nn.Module):
    """
        Convolution Unit: (Conv3D -> BatchNorm -> ReLu) * 2
    """
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.double_conv = nn.Sequential(
            nn.Conv3d(in_channels, out_channels, kernel_size = 3, padding = 1),
            nn.BatchNorm3d(out_channels),
            nn.ReLU(inplace=True), # inplace=True means it changes the input directly, input is lost

            #nn.Conv3d(out_channels, out_channels, kernel_size = 3, padding = 1),
            #nn.BatchNorm3d(out_channels),
            #nn.ReLU(inplace=True)
          )

    def forward(self,x):
        return self.double_conv(x)

class EncoderUnit(nn.Module):
    """
    An Encoder Unit with the ConvUnit and MaxPool
    """
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.MaxPool3d(2),
            ConvUnit(in_channels, out_channels)
        )
    def forward(self, x):
        return self.encoder(x)

class DecoderUnit(nn.Module):
    """
    ConvUnit and upsample with Upsample or convTranspose
    """
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.ConvTranspose3d(in_channels // 2, in_channels // 2, kernel_size=2, stride=2)
        self.conv = ConvUnit(in_channels, out_channels)

    def forward(self, x1, x2):
        x1 = self.up(x1)

        diffZ = x2.size()[2] - x1.size()[2]
        diffY = x2.size()[3] - x1.size()[3]
        diffX = x2.size()[4] - x1.size()[4]
        x1 = F.pad(x1, [diffX // 2, diffX - diffX // 2, diffY // 2, diffY - diffY // 2, diffZ // 2, diffZ - diffZ // 2])

        x = torch.cat([x2, x1], dim=1)
        return self.conv(x)

class OutConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv = nn.Conv3d(in_channels, out_channels, kernel_size = 1)

    def forward(self, x):
        return self.conv(x)

class Unet3d(nn.Module):
    def __init__(self, in_channels, n_classes, s_channels):
        super().__init__()
        self.in_channels = in_channels
        self.n_classes = n_classes
        self.s_channels = s_channels

        self.conv = ConvUnit(in_channels, s_channels)
        self.enc1 = EncoderUnit(s_channels, 2 * s_channels)
        self.enc2 = EncoderUnit(2 * s_channels, 4 * s_channels)
        self.enc3 = EncoderUnit(4 * s_channels, 8 * s_channels)
        self.enc4 = EncoderUnit(8 * s_channels, 8 * s_channels)

        self.dec1 = DecoderUnit(16 * s_channels, 4 * s_channels)
        self.dec2 = DecoderUnit(8 * s_channels, 2 * s_channels)
        self.dec3 = DecoderUnit(4 * s_channels, s_channels)
        self.dec4 = DecoderUnit(2 * s_channels, s_channels)
        self.out = OutConv(s_channels, n_classes)

    def forward(self, x):
        x1 = self.conv(x)
        x2 = self.enc1(x1)
        x3 = self.enc2(x2)
        x4 = self.enc3(x3)
        x5 = self.enc4(x4)

        x6 = self.dec1(x5, x4)
        x7 = self.dec2(x6, x3)
        x8 = self.dec3(x7, x2)
        x9 = self.dec4(x8, x1)
        output = self.out(x9)
        return output 
        
# SCNET 3D

features = 4
dilation = [1,1,1]

# 4 features goes through test


class SCNET(nn.Module): # need to add bottleneck
    
    def __init__(self, in_channels, out_channels):
        super().__init__()
        
        #initialise sigma to model
        
        # Local appearance
        
        # initialise sigma
        #self.
        

        # block 1
        self.conv1 = self.conv_block1(in_channels, features, 3, 1) 
        self.conv2 = self.conv_block1(features, features, 3, 1)
        self.conv3 = self.conv_block1(features,features,3, 1)

        # block 2
        self.pool_block_2 = self.pool_layer_block_2()

        # block 3
        self.conv4 = self.conv_block3(features, features, 3, 1) # note conv4 acts on pool, which acts on conv2
        self.conv5 = self.conv_block3(features, features, 3, 1)
        self.conv6 = self.conv_block3(features,features,3, 1)

        # block 4
        self.pool_block_4 = self.pool_layer_block_4()

        # block 5
        self.conv7 = self.conv_block5(features, features, 3, 1) # note conv7 acts on pool, which acts on conv5
        self.conv8 = self.conv_block5(features, features, 3, 1)
        self.conv9 = self.conv_block5(features,features,3, 1)

        # block 6
        self.upsample_block_6 = self.upsample_layer_block_6(features)

        # block 7
        # addition
        self.upsample_block_7 = self.upsample_layer_block_7(features)


        # block 8
        # addition
        self.conv10 = self.conv_block8(features, out_channels, 3, 1)

        # Spatial configuration

        # block 9
        self.pool_block_9 = self.pool_layer_block_9()

        # block 10
        self.conv11 = self.conv_block10(out_channels, features, 3, 1) 
        self.conv12 = self.conv_block10(features, features, 3, 1)
        self.conv13 = self.conv_block10(features,features,3, 1)

        # block 11
        self.upsample_block_11 = self.upsample_layer_block_11(features, out_channels)

        # block 12
        # multiplication


    def __call__(self, x):

        # block 1
        conv1 = self.conv1(x)
        conv2 = self.conv2(conv1)
        conv3 = self.conv3(conv2)

        # block 2
        pool_block_2 = self.pool_block_2(conv2) # note middle one

        # block 3
        conv4 = self.conv4(pool_block_2)
        conv5 = self.conv5(conv4)
        conv6 = self.conv6(conv5)

        # block 4
        pool_block_4 = self.pool_block_4(conv5)

        # block 5
        conv7 = self.conv7(pool_block_4)
        conv8 = self.conv8(conv7)
        conv9 = self.conv9(conv8)

        # block 6
        upsample_block_6 = self.upsample_block_6(conv9)

        # block 7
        add_block_7 = conv6 + upsample_block_6
        upsample_block_7 = self.upsample_block_7(add_block_7)

        # block 8
        add_block_8 = upsample_block_7 + conv3
        conv10 = self.conv10(add_block_8)

        # block 9
        pool_block_9 = self.pool_block_9(conv10)

        # block 10
        conv11 = self.conv11(pool_block_9)
        conv12 = self.conv12(conv11)
        conv13 = self.conv13(conv12)

        # block 11
        upsample_block_11 = self.upsample_block_11(conv13)

        # block 12
        output = upsample_block_11 * conv10

        return output

    def conv_block1(self, in_channels, out_channels, kernel_size, padding):

        conv_block1 = nn.Sequential(
            nn.Conv3d(in_channels, out_channels, kernel_size = kernel_size, stride = 1, dilation = dilation, padding = padding), # add dilation
            nn.BatchNorm3d(out_channels),
            nn.LeakyReLU()
        )
        return conv_block1

    def pool_layer_block_2(self):

        pool_layer_block_2 = nn.Sequential(
            nn.AvgPool3d(kernel_size=2, stride=2, padding=0)
        )

        return pool_layer_block_2
    
    def conv_block3(self, in_channels, out_channels, kernel_size, padding):

        conv_block2 = nn.Sequential(
            nn.Conv3d(in_channels, out_channels, kernel_size = kernel_size, stride = 1, dilation = dilation, padding = padding), # add dilation
            nn.BatchNorm3d(out_channels),
            nn.LeakyReLU()
        )
        return conv_block2

    def pool_layer_block_4(self):

        pool_layer_block_4 = nn.Sequential(
            nn.AvgPool3d(kernel_size=2, stride=2, padding=0)
        )

        return pool_layer_block_4
    
    def conv_block5(self, in_channels, out_channels, kernel_size, padding):

        conv_block5 = nn.Sequential(
            nn.Conv3d(in_channels, out_channels, kernel_size = kernel_size, stride = 1, dilation = dilation, padding = padding), # add dilation
            nn.BatchNorm3d(out_channels),
            nn.LeakyReLU()
        )
        return conv_block5
    
    def upsample_layer_block_6(self, channels):

        upsample_block_6 = nn.Sequential(
          nn.ConvTranspose3d(channels, channels, kernel_size = 3, stride = 2, padding = 1, output_padding=1) # add dilation
        )
        return upsample_block_6
    
    def upsample_layer_block_7(self, channels):

        upsample_block_7 = nn.Sequential(
          nn.ConvTranspose3d(channels, channels, kernel_size = 3, stride = 2, padding = 1, dilation = dilation, output_padding=1) # add dilation
        )
        return upsample_block_7

    def conv_block8(self, in_channels, out_channels, kernel_size, padding):

        conv_block8 = nn.Sequential(
            nn.Conv3d(in_channels, out_channels, kernel_size = kernel_size, stride = 1, dilation = dilation, padding = padding), # add dilation
            nn.BatchNorm3d(out_channels),
            nn.LeakyReLU()
        )
        return conv_block8

    def pool_layer_block_9(self):

        pool_layer_block_9 = nn.Sequential(
            nn.AvgPool3d(kernel_size=2, stride=2, padding=0)
        )

        return pool_layer_block_9

    def conv_block10(self, in_channels, out_channels, kernel_size, padding):

        conv_block10 = nn.Sequential(
            nn.Conv3d(in_channels, out_channels, kernel_size = kernel_size, stride = 1, dilation = dilation, padding = padding), # add dilation
            nn.BatchNorm3d(out_channels),
            nn.LeakyReLU()
        )
        return conv_block10

    def upsample_layer_block_11(self, in_channels, out_channels):

        upsample_block_11 = nn.Sequential(
          nn.ConvTranspose3d(in_channels, out_channels, kernel_size = 3, stride = 2, padding = 1,dilation = dilation, output_padding=1) # add dilation
        )
        return upsample_block_11


# Model summary

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Unet3d(1,num_class, unet_feat)
model = model.to(device)

from torchsummary import summary
summary(model, input_size=(1, in_y, in_x, in_z))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─ConvUnit: 1-1                          --
# |    └─Sequential: 2-1                   --
# |    |    └─Conv3d: 3-1                  112
# |    |    └─BatchNorm3d: 3-2             8
# |    |    └─ReLU: 3-3                    --
# ├─EncoderUnit: 1-2                       --
# |    └─Sequential: 2-2                   --
# |    |    └─MaxPool3d: 3-4               --
# |    |    └─ConvUnit: 3-5                888
# ├─EncoderUnit: 1-3                       --
# |    └─Sequential: 2-3                   --
# |    |    └─MaxPool3d: 3-6               --
# |    |    └─ConvUnit: 3-7                3,504
# ├─EncoderUnit: 1-4                       --
# |    └─Sequential: 2-4                   --
# |    |    └─MaxPool3d: 3-8               --
# |    |    └─ConvUnit: 3-9                13,920
# ├─EncoderUnit: 1-5                       --
# |    └─Sequential: 2-5                   --
# |    |    └─MaxPool3d: 3-10              --
# |    |    └─ConvUnit: 3-11               27,744
# ├─DecoderUnit: 1-6                       --
# |    └─ConvTranspose3d: 2-6              8,224
# |    └─ConvUnit: 2-7                     --
# |    |    └─Sequential: 3-12             27,696
# ├─DecoderUnit: 1-7                       --
# |    └─ConvTranspose3d: 2-8              2,064
# |    └─ConvUnit: 2-9                     --
# |    |    └─Sequential: 3-13             6,936
# ├─DecoderUnit: 1-8                       --
# |    └─ConvTranspose3d: 2-10             520
# |    └─ConvUnit: 2-11                    --
# |    |    └─Sequential: 3-14             1,740
# ├─DecoderUnit: 1-9                       --
# |    └─ConvTranspose3d: 2-12             132
# |    └─ConvUnit: 2-13                    --
# |    |    └─Sequential: 3-15             876
# ├─OutConv: 1-10                          --
# |    └─Conv3d: 2-14                      5
# =================================================================
# Total params: 94,369
# Trainable params: 94,369
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─ConvUnit: 1-1                          --
# |    └─Sequential: 2-1                   --
# |    |    └─Conv3d: 3-1                  112
# |    |    └─BatchNorm3d: 3-2             8
# |    |    └─ReLU: 3-3                    --
# ├─EncoderUnit: 1-2                       --
# |    └─Sequential: 2-2                   --
# |    |    └─MaxPool3d: 3-4               --
# |    |    └─ConvUnit: 3-5                888
# ├─EncoderUnit: 1-3                       --
# |    └─Sequential: 2-3                   --
# |    |    └─MaxPool3d: 3-6               --
# |    |    └─ConvUnit: 3-7                3,504
# ├─EncoderUnit: 1-4                       --
# |    └─Sequential: 2-4                   --
# |    |    └─MaxPool3d: 3-8               --
# |    |    └─ConvUnit: 3-9                13,920
# ├─EncoderUnit: 1-5                       --
# |    └─Sequential: 2-5                   --
# |    |    └─MaxPool3d: 3-10              --
# |    |    └─ConvUnit: 3-11               27,744
# ├─DecoderUnit: 1-6                       --
# |    └─ConvTranspose3d: 2-6              8,224
# |    └─ConvUnit: 2-7                     --
# |    |    └─Sequential: 3-12             27,696
# ├─DecoderUnit: 1-7                       --
# |    └─ConvTranspose3d: 2-8              2,064
# |    └─ConvUnit: 2-9                     --
# |    |    └─Sequential: 3-13             6,936
# ├─DecoderUnit: 1-8                       --
# |    └─ConvTranspose3d: 2-10             520
# |    └─ConvUnit: 2-11                    --
# |    |    └─Sequential: 3-14             1,740
# ├─DecoderUnit: 1-9                       --
# |    └─ConvTranspose3d: 2-12             132
# |    └─ConvUnit: 2-13                    --
# |    |    └─Sequential: 3-15             876
# ├─OutConv: 1-10                          --
# |    └─Conv3d: 2-14                      5
# =================================================================
# Total params: 94,369
# Trainable params: 94,369
# Non-trainable params: 0
# =================================================================

# %%
# more useful functions

import sys, csv ,operator


def point_to_point(mask_x, mask_y, mask_z, pred_x, pred_y, pred_z):
  # calculates point to point error for image
  point_to_point = ((pred_x - mask_x)**2 + (pred_y - mask_y)**2 + (pred_z - mask_z)**2)**0.5 
  return point_to_point

def point_to_point_mm(mask_x, mask_y, mask_z, pred_x, pred_y, pred_z, image_idx):
  # calculates point to point in mm
  data = csv.reader(open(os.path.join(root, 'image_dimensions.csv')),delimiter=',')
  next(data) # skip first line
  sortedlist = sorted(data, key=operator.itemgetter(0))
  # sortedlist[img_number][0 = name, 1 = x/y, 2 = z]
  image_idx = int(image_idx)
  pixel_mm_x = sortedlist[image_idx][1]# 1 pixel = pixel_mm_x * mm
  pixel_mm_y = sortedlist[image_idx][1]
  pixel_mm_z = sortedlist[image_idx][2]
  pixel_mm_x = torch.tensor(float(pixel_mm_x)).to(device)
  pixel_mm_y = torch.tensor(float(pixel_mm_y)).to(device)
  pixel_mm_z = torch.tensor(float(pixel_mm_z)).to(device)
  point_to_point = (((pred_x - mask_x)*pixel_mm_x)**2 + ((pred_y - mask_y)*pixel_mm_y)**2 + ((pred_z - mask_z)*pixel_mm_z)**2)**0.5 
  return point_to_point


def gaussian(x,y,z, targ_coords, sigma, gamma, dimension = 3): # assumes in 2d space
  # x, y are general coords and targ_coords define mean of gaussian
  x_targ, y_targ, z_targ = targ_coords[0], targ_coords[1], targ_coords[2]
  l2_dif = torch.tensor(-((x-x_targ)**2 + (y- y_targ)**2 + (z-z_targ)**2)/(2*sigma**2)).to(device)
  gauss = torch.tensor((gamma) * (2*np.pi)**(-dimension/2) * sigma ** (-dimension) ** torch.exp(l2_dif)).to(device)
  return gauss

def gaussian_map(peak_x,peak_y,peak_z, sigma,gamma,x_size,y_size, z_size, output,dimension = 3): # 2D gaussian 5x5 image
  if output == False: # expands gaussian map to 448x448 to ensure proper normalisation ? not working
    y,x,z = np.ogrid[0:2*y_size,0:2*x_size, 0:2*z_size]
    peak_x = peak_x + x_size/2
    peak_y = peak_y + y_size/2
    peak_z = peak_z + z_size/2
    pre_factor = ((gamma) * (2*np.pi)**(-dimension/2) * sigma ** (-dimension)) 
    h = pre_factor * torch.exp( -((torch.tensor(x).to(device)-peak_x)**2 + (torch.tensor(y).to(device)-peak_y)**2 + (torch.tensor(z).to(device)-peak_z)**2) / (2.*sigma*sigma) )
  if output == True:
    y,x,z = np.ogrid[0:y_size,0:x_size, 0:z_size]
    pre_factor = ((gamma) * (2*np.pi)**(-dimension/2) * sigma ** (-dimension)) 
    h = pre_factor * torch.exp( -((torch.tensor(x).to(device)-peak_x)**2 + (torch.tensor(y).to(device)-peak_y)**2 + ((torch.tensor(z).to(device)-peak_z)*x_size/z_size)**2) / (2.*sigma*sigma) )
    # note multiply to ensure spherical
  return h

# new gaussian map function produces gaussian target based on every location of landmark in target
def gaussian_map_expansive(landmarks, landmarks_size, sigma, gamma, x_size, y_size, z_size, dimension =3):
  # x/y/z_landmarks gives multiple locations of landmark
  y,x,z = np.ogrid[0:y_size,0:x_size, 0:z_size]
  pre_factor = ((gamma) * (2*np.pi)**(-dimension/2) * sigma ** (-dimension)) 
  h = torch.tensor().to(device) # not sure what size it is can work out from gaussian_map
  for i in range(landmarks_size):
    peak_x, peak_y, peak_z = landmarks[i][0], landmarks[i][1], landmarks[i][2]
    h += pre_factor * torch.exp( -((torch.tensor(x).to(device)-peak_x)**2 + (torch.tensor(y).to(device)-peak_y)**2 + (torch.tensor(z).to(device)-peak_z)**2) / (2.*sigma*sigma) )
  return h


def print_metrics(metrics,  epoch_samples, phase): # not sure??
    print('Phase: Landmark, Value')
    for l in metrics.keys():
        output_per_landmark = []
        for k in metrics[l].keys():
            output_per_landmark.append("{}: {:4f}".format((l,k), metrics[l][k]/epoch_samples))
        print("{}: {}".format(phase, ", ".join(output_per_landmark)))

def weights_init(m):
    if isinstance(m, nn.Conv2d):
        torch.nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu') # change if switch to ReLU
        torch.nn.init.zeros_(m.bias)

# %%
# l2 loss function

def calc_loss_gauss(img, pred, target, idx, metrics_landmarks, alpha, reg, gamma, epoch_samples, sigma): 

    # pred is Batch x Classes x Height x Width x Depth
    # target is Batch x 1 x Height x Width x Depth

    # loss function for difference between gaussian heat maps
    # pred is gaussian heatmap & need to convert target to gaussian heatmap

    # target is 3D CT scan of 1s, 2s, 3s, 4s, 5s, 6s
    # need to calculate max coord for each landmark 

    # i.e. metrics_landmarks[3]['loss'] is loss for landmark denoted by 3
    # metrics is defined per epoch

    # need to calculate total loss for each landmark but also store loss per landmark

    # cumulative over all landmarks
    loss_for_all_landmarks = 0
    total_batch_loss = 0
    total_sum_loss = 0
    total_reg_loss = 0
    total_alpha_loss = 0
    total_point_to_point = 0
    
    for l in landmarks:

      # need location of landmark for all images in target 3D CT scan
      target_coords = com_structure(target,l)[0] # the [0] means it extracts the coords rather than the True/False
      # change to top structure
      batch_size = target_coords.size()[0]
      
      # location of prediction for all images 
      pred_coords_max = pred_max(pred, l) # don't change to gauss fit as gauss fit takes too long
     
      # per landmark
      total_x_posn_landmark = 0
      total_y_posn_landmark = 0
      total_z_posn_landmark = 0
      total_x_targ_posn_landmark = 0
      total_y_targ_posn_landmark = 0
      total_z_targ_posn_landmark = 0
      total_point_to_point_landmark = 0
    
      # for every image in batch
      for i in range(batch_size): 

        img_number = epoch_samples + i # epoch_samples is 0, 32, 64 e.g. if batch is size 32
      
        x_size = target.size()[3]
        y_size = target.size()[2] 
        z_size = target.size()[4]

        # structure location per image
        structure_com_x, structure_com_y, structure_com_z = target_coords[i][0],target_coords[i][1], target_coords[i][2] 

        # pred location per image
        pred_max_x, pred_max_y, pred_max_z =  pred_coords_max[i][0], pred_coords_max[i][1], pred_coords_max[i][2] 

        # average x/y posn
        total_x_posn_landmark += pred_max_x
        total_y_posn_landmark += pred_max_y
        total_z_posn_landmark += pred_max_z
        total_x_targ_posn_landmark += structure_com_x
        total_y_targ_posn_landmark += structure_com_y
        total_z_targ_posn_landmark += structure_com_z

        # point to point per landmark per image
        img_landmark_point_to_point = point_to_point(structure_com_x, structure_com_y, structure_com_z, pred_max_x, pred_max_y, pred_max_z)
        #img_landmark_point_to_point = point_to_point_mm(structure_com_x, structure_com_y, structure_com_z, pred_max_x, pred_max_y, pred_max_z, idx[i].item())

        # create target gauss map
        if com_structure(target,l)[1][i] == True:
        # change to top structure
          targ_gaus = gaussian_map(structure_com_x,structure_com_y, structure_com_z,sigmas[l],gamma,x_size,y_size,z_size, output = True) 
        else:
          # target is full of zeros
          targ_gaus = torch.zeros(target.size()[2], target.size()[3], target.size()[4]).to(device)

        # pred heatmap is based on image in batch & landmark
        index = landmarks.index(l)
        pred_heatmap = pred[i][index]
        # l - 1 because l is 1,2,3,4,5,6
        
        # img_loss and sum_loss per landmark
        img_loss = ((((pred_heatmap - targ_gaus)**2)).sum()) # multiply by targ gaus for box normalisation
        sum_loss = ((((pred_heatmap - targ_gaus)**2)).sum())
        
        # just to see
        #if sum_loss < 10:
        #    print_3D_heatmap(img.squeeze(0), target.squeeze(0), pred.squeeze(0), l)
            
        
        # regularization term
        squ_weights = torch.tensor(0,dtype=torch.float64).to(device)
        for model_param_name, model_param_value in model.named_parameters():
          if model_param_name.endswith('weight'):
            squ_weights += (model_param_value.norm())**2
        
        regularization = (reg * squ_weights)
        reg_loss = regularization
        
        img_loss += alpha * (sigmas[l].norm())**2 + regularization
        alpha_loss = alpha * (sigmas[l].norm())**2

        # add to total loss
        total_batch_loss += img_loss
        total_sum_loss += sum_loss
        total_reg_loss += reg_loss
        total_alpha_loss += alpha_loss
        total_point_to_point += img_landmark_point_to_point



        # need to add data to metrics per landmark
        metrics_landmarks[l]['loss'] += img_loss.data.cpu().numpy() # loss per image per landmark
        metrics_landmarks[l]['sum loss'] += sum_loss.data.cpu().numpy() # sum loss per image per landmark
        metrics_landmarks[l]['reg loss'] += reg_loss.data.cpu().numpy() # reg loss per image per landmark
        metrics_landmarks[l]['alpha loss'] += alpha_loss.data.cpu().numpy() # alpha loss per image per landmark
        metrics_landmarks[l]['mean x pred'] += pred_max_x.data.cpu().numpy() # x posn per image per landmark
        metrics_landmarks[l]['mean y pred'] += pred_max_y.data.cpu().numpy() # y posn per image per landmark
        metrics_landmarks[l]['mean z pred'] += pred_max_z.data.cpu().numpy() # z posn per image per landmark
        metrics_landmarks[l]['mean x targ'] += structure_com_x.data.cpu().numpy() # x targ per image per landmark
        metrics_landmarks[l]['mean y targ'] += structure_com_y.data.cpu().numpy() # y targ per image per landmark
        metrics_landmarks[l]['mean z targ'] += structure_com_z.cpu().numpy() # z targ per image per landmark
        metrics_landmarks[l]['mean point to point'] += img_landmark_point_to_point.data.cpu().numpy() # p2p per image per landmark
      
      # average per landmark over batches
      metrics_landmarks[l]['loss'] /= batch_size * target.size()[0] # loss per batch per landmark
      metrics_landmarks[l]['sum loss'] /= batch_size * target.size()[0]# sum loss per batch per landmark
      metrics_landmarks[l]['reg loss'] /= batch_size * target.size()[0]# reg loss per batch per landmark
      metrics_landmarks[l]['alpha loss'] /= batch_size * target.size()[0]# alpha loss per batch per landmark
      metrics_landmarks[l]['mean x pred'] /= batch_size * target.size()[0] # x posn per batch per landmark
      metrics_landmarks[l]['mean y pred'] /= batch_size * target.size()[0] # y posn per batch per landmark
      metrics_landmarks[l]['mean z pred'] /= batch_size * target.size()[0] # z posn per batch per landmark
      metrics_landmarks[l]['mean x targ'] /= batch_size * target.size()[0] # x targ per batch per landmark
      metrics_landmarks[l]['mean y targ'] /= batch_size * target.size()[0] # y targ per batch per landmark
      metrics_landmarks[l]['mean z targ'] /= batch_size * target.size()[0] # z targ per batch per landmark
      metrics_landmarks[l]['mean point to point'] /= batch_size * target.size()[0] # p2p per batch per landmark


      # print for every epoch_samples = 0 -> i.e first image in epoch
      if epoch_samples == 0:
        if l == landmarks[0]:
          print('------- First image of set --------')
        print('Landmark %1.0f' % l)
        print('--------------')
        print('targ: (%5.2f,%5.2f,%5.2f)' % (structure_com_x,structure_com_y,structure_com_z))
        print('pred: (%5.2f,%5.2f,%5.2f)' % (pred_max_x,pred_max_y,pred_max_z))
        # predicted coordinates
        print('point to point')
        print(img_landmark_point_to_point)
        print('img loss')
        print(img_loss)
        # plot predicted and target heatmap

          
    # return mean batch loss
    mean_batch_loss = (total_batch_loss/batch_size)
    
    return mean_batch_loss

# metrics was here in chain previously

# %%
# train model function


def train_model(model,scaler, optimizer, scheduler,alpha,reg,gamma,sigmas,num_epochs,best_loss):
    best_model_wts = copy.deepcopy(model.state_dict())

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        since = time.time()

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                scheduler.step()
                for param_group in optimizer.param_groups:
                    print("LR", param_group['lr'])

                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            metrics_total = defaultdict(float)
            metrics_landmarks = defaultdict(float)
            for i in landmarks:
              metrics_landmarks[i] = defaultdict(float) 
            # i.e. metrics_landmarks[3]['loss'] is loss for landmark denoted by 3

            epoch_samples = 0
      
            batch_number = 1
            for batch in dataloaders[phase]:
                    inputs = batch['image']
                    labels = batch['structure']
                    idx = batch['idx']
                   # print(labels.size())
                    inputs = inputs.float().to(device)
                    labels = labels.float().to(device)

                    # zero the parameter gradients
                    #print('zero the grad')
                    #optimizer.zero_grad() 
                    # amp mod
                    #print(optimizer.parameter())
                    #sigma.zero_grad

                    # forward
                    # track history only if in train
                    with torch.set_grad_enabled(phase == 'train'):
                        
                        with torch.cuda.amp.autocast(enabled = use_amp):
                            outputs = model((inputs))
                            # 1. convert masks to heatmaps inside loss function (allows sigma optimisation)
                            loss = calc_loss_gauss(inputs, outputs, labels, idx, metrics_landmarks,alpha,reg,gamma,epoch_samples,sigmas)
                        
                        # print image for comparison
                        if epoch_samples == 0:
                          # plot image
                          print(' ---- first image of set ---- (end)')
                        # 2. vs convert to heatmap here means no sigma optimisation


                        # backward + optimize only if in training phase
                        if phase == 'train':
                            scaler.scale(loss).backward()
                            # only step once per epoch
                            #if (batch_number % batch_accumulation == 0) or (batch_number % 10 == 0):
                            #print('reached', batch_number, batch_accumulation)
                            scaler.step(optimizer)
                            scaler.update() 
                            scheduler.step()
                            optimizer.zero_grad()
                                


                    # statistics
                    epoch_samples += inputs.size(0)
                    batch_number += 1

            
            print_metrics(metrics_landmarks, epoch_samples, phase)
            #print('The following have zero requires grad:')
            #all_have_grad = True
            #for name, param in model.named_parameters():
            #  if param.requires_grad == False:
            #      print (name)
            #      all_have_grad = False
            #if (all_have_grad == True):
            #  print('All parameters have require grad = true')      
            print('Sigmas are')
            for l in landmarks:
              print(sigmas[l])
          
            
            epoch_loss = 0
            for l in landmarks:
                epoch_loss += metrics_landmarks[l]['loss']
            epoch_loss /= epoch_samples
            

            # deep copy the model
            if phase == 'val' and epoch_loss < best_loss:
                print("saving best model")
                best_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())
                

        time_elapsed = time.time() - since
        finish_time = time.ctime(time_elapsed * (num_epochs - epoch) + time.time())
        print('{:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
        print('Estimated finish time: ', finish_time)

    print('Best val loss: {:4f}'.format(best_loss))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, best_loss

# %%
# evaluate model functions

def extract_landmark_for_structure(structure, landmark):
  landmark = float(landmark)
  zero_tensor = torch.zeros(structure.size(), dtype = torch.float).to(device)

  min = landmark - 0.1
  max = landmark + 0.1 # small range around int

  min = float(min)
  max = float(max)

  print(structure.type())
  print(zero_tensor.type())

  a = torch.where(structure > min, structure, zero_tensor)
  b = torch.where(a < max, a, zero_tensor)


  return b


# for pred/structure & image
def plot_3d_pred_img_struc(image, structure, pred, threshold_img):
    
    verts_structure, faces_structure = measure.marching_cubes_classic(structure)#, threshold_structure)
    verts_img, faces_img = measure.marching_cubes_classic(image, threshold_img)
    verts_pred, faces_pred = measure.marching_cubes_classic(pred)#, threshold_pred)

    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')

    # Fancy indexing: `verts[faces]` to generate a collection of triangles
    mesh_img = Poly3DCollection(verts_img[faces_img], alpha=0.1)
    mesh_structure = Poly3DCollection(verts_structure[faces_structure], alpha=0.6)
    mesh_pred = Poly3DCollection(verts_pred[faces_pred], alpha=0.2)

    #face_color_img = [0.5, 0.5, 1]
    face_color_img = ['tab:gray']
    mesh_img.set_facecolor(face_color_img)

    face_color_structure = ['r', 'b', 'g']
    mesh_structure.set_facecolor(face_color_structure)

    face_color_pred = ['y', 'm', 'c']
    mesh_pred.set_facecolor(face_color_pred)


    ax.add_collection3d(mesh_img)
    ax.add_collection3d(mesh_structure)
    #ax.add_collection3d(mesh_pred)

    ax.set_xlim(0, image.shape[1])
    ax.set_ylim(0, image.shape[0])
    ax.set_zlim(0, image.shape[2])

    ax.invert_xaxis()

    # rotate the axes and update
    ax.mouse_init(rotate_btn=1, zoom_btn=3)

    plt.show()
    
def plot_3d_pred_img_struc_no_img(structure, pred):
    
    verts_structure, faces_structure = measure.marching_cubes_classic(structure)#, threshold_structure)
    verts_pred, faces_pred = measure.marching_cubes_classic(pred)#, threshold_pred)

    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')

    # Fancy indexing: `verts[faces]` to generate a collection of triangles
   
    mesh_structure = Poly3DCollection(verts_structure[faces_structure], alpha=0.6)
    mesh_pred = Poly3DCollection(verts_pred[faces_pred], alpha=0.2)

   

    face_color_structure = ['r', 'b', 'g']
    mesh_structure.set_facecolor(face_color_structure)

    face_color_pred = ['y', 'm', 'c']
    mesh_pred.set_facecolor(face_color_pred)


  
    ax.add_collection3d(mesh_structure)
    ax.add_collection3d(mesh_pred)

    ax.set_xlim(0, structure.shape[1])
    ax.set_ylim(0, structure.shape[0])
    ax.set_zlim(0, structure.shape[2])

    ax.invert_xaxis()

    # rotate the axes and update
    ax.mouse_init(rotate_btn=1, zoom_btn=3)

    plt.show()

import matplotlib.cm as cm
    
def print_2D_slice(image, structure, pred, landmark, pred_z):
    
    # image
    # - C x H x W x D needs to be cut down to H x W x D
    # structure
    # - C x H x W x D needs to be cut down to H x W x D
    # - currently has all landmarks in but need to plot only 1 landmark - l
    # pred
    # - C x H x W x D needs to be cut down to H x W x D
    # - not sure what values of this heatmap will be so not sure what threshold should be
    image = image.squeeze(0).cpu().numpy()
    index = landmarks.index(landmark)
    pred = pred[index].detach().cpu().numpy() # chooses relevant channel for landmark - might need to be squeezed
    structure = structure.squeeze(0)
    structure_l = extract_landmark_for_structure(structure, landmark).cpu().numpy() # edit
    structure = structure.cpu().numpy()
    
    plt.figure()
    
    pred_z = int(pred_z) # convert to nearest int

    image = image[:, :, pred_z]
    structure_l = structure_l[:, :, pred_z]
    pred = pred[:, :, pred_z]

    plt.imshow(image,cmap = 'Greys_r', alpha = 0.5)
    #plt.imshow(structure_l, cmap = 'Reds', alpha = 0.8 )
    plt.imshow(pred, cmap = cm.jet, alpha = 0.5)

    plt.show()

    
    
def print_3D_heatmap(image, structure, pred, landmark):
  # image
  # - C x H x W x D needs to be cut down to H x W x D
  # structure
  # - C x H x W x D needs to be cut down to H x W x D
  # - currently has all landmarks in but need to plot only 1 landmark - l
  # pred
  # - C x H x W x D needs to be cut down to H x W x D
  # - not sure what values of this heatmap will be so not sure what threshold should be

  structure_max = torch.max(structure).item()

  image = image.squeeze(0).cpu().numpy()
  index = landmarks.index(landmark)
  pred = pred[index].detach().cpu().numpy() # chooses relevant channel for landmark - might need to be squeezed
  structure = structure.squeeze(0)
  structure_1 = extract_landmark_for_structure(structure, landmark).cpu().numpy() # edit
  structure = structure.cpu().numpy()

  threshold_img = threshold_img_print
  #threshold_structure = structure_max # unused
  #threshold_pred = threshold_pred_print # unused


  plot_3d_pred_img_struc(image, structure_1, pred, threshold_img)

def print_3D_heatmap_no_img(structure, pred, landmark):
  # - C x H x W x D needs to be cut down to H x W x D
  # - currently has all landmarks in but need to plot only 1 landmark - l
  # pred
  # - C x H x W x D needs to be cut down to H x W x D
  # - not sure what values of this heatmap will be so not sure what threshold should be

  structure_max = torch.max(structure).item()
    
  index = landmarks.index(landmark)
  pred = pred[index].detach().cpu().numpy() # chooses relevant channel for landmark - might need to be squeezed
  structure = structure.squeeze(0)
  structure_1 = extract_landmark_for_structure(structure, landmark).cpu().numpy() # edit
  structure = structure.cpu().numpy()

  #threshold_structure = structure_max # unused
  #threshold_pred = threshold_pred_print # unused


  plot_3d_pred_img_struc_no_img(structure_1, pred)

# print structure as 3D gauss and then print prediction heatmap and the max of it 
def print_3D_gauss_heatmap(image, structure_com_x, structure_com_y, structure_com_z, pred, landmark, sigma):
  # image
  # - C x H x W x D needs to be cut down to H x W x D
  # structure_com
  # - use gaussian_map to make gaussian map from structure
  # - this needs to be only for the desired landmark
  # pred
  # - print

  image = image.squeeze(0).cpu().numpy()
  x_size = image.shape[1]
  y_size = image.shape[0]
  z_size = image.shape[2]
  structure_gauss = gaussian_map(structure_com_x,structure_com_y,structure_com_z, sigma,gamma,x_size,y_size, z_size, output = True,dimension = 3).detach().cpu()
  index = landmarks.index(landmark)
  pred = pred[index].detach().cpu().numpy() # chooses relevant channel for landmark - might need to be squeezed


  threshold_img = threshold_img_print
  #threshold_structure = landmark # unuused
  #threshold_pred = threshold_pred_print # unused

  plot_3d_pred_img_struc(image, structure_gauss, pred, threshold_img)



def performance_metrics(model,sigmas,gamma):
  p2p_landmarks = defaultdict(float)
  outliers_landmarks = defaultdict(float)
  for l in landmarks:
    p2p_landmarks[l] = np.empty((0), float)
    outliers_landmarks[l] = np.empty((0), float)


  for batch in dataloaders['test']:
    image = batch['image'].to(device)
    structure = batch['structure'].to(device)
    idx = batch['idx'].to(device)
    pred = model(image)
  
    batch_number = 0
    
    for l in landmarks: # cycle over all landmarks
      
      for i in range(batch_size):
        
        structure_com = com_structure(structure, l)[0] # [0] ensures extracts coords rather than True/False
        # change to top structure
        if com_structure(structure,1)[1][i] == True:
        # change to top structure
          pred_coords_max = pred_max(pred, l) # change to gauss fit
          dimension = 3
          height_guess = ((gamma) * (2*np.pi)**(-dimension/2) * sigmas[l].item() ** (-dimension)) 
          print(pred.shape)
          #pred_coords_max = gauss_max(pred,l,height_guess,sigmas[l].item())  
          
          structure_max_x, structure_max_y, structure_max_z = structure_com[i][0],structure_com[i][1], structure_com[i][2] 
          pred_max_x, pred_max_y, pred_max_z =  pred_coords_max[i][0], pred_coords_max[i][1], pred_coords_max[i][2] 


          # print out 3D images for first one in batc
          if batch_number == 0 and i == 0: # for first batch 
            # now need to choose first in batch i.e. # image[0]
            print('3D plots for landmark %1.0f' % l)
            print_3D_heatmap(image[i], structure[i], pred[i], l)
            #print_3D_gauss_heatmap(image[i], structure_max_x, structure_max_y, structure_max_z, pred[i], l, sigmas[l])
            print('Structure COM:')
            print(structure_max_x, structure_max_y, structure_max_z)
            print('Predicted COM:')
            print(pred_max_x, pred_max_y, pred_max_z)
            # print 2D slice
            #print('2D slice for landmark %1.0f' % l)
            #print_2D_slice(image[i], structure[i], pred[i], l, pred_max_z)
            

          #img_landmark_point_to_point = point_to_point(structure_max_x, structure_max_y, structure_max_z, pred_max_x, pred_max_y, pred_max_z)
          img_landmark_point_to_point = point_to_point_mm(structure_max_x, structure_max_y, structure_max_z, pred_max_x, pred_max_y, pred_max_z, idx[i].item())
          p2p_landmarks[l] = np.append(p2p_landmarks[l],img_landmark_point_to_point.cpu())
          # if img_point_to_point > 20mm is an outlier
          if img_landmark_point_to_point > 20:
            outliers_landmarks[l] = np.append(outliers_landmarks[l],1)

    batch_number += 1 # not sure where to put
  
  for l in landmarks:
    print('\n')
    print('Landmark %1.0f' % l)
    mean = np.mean(p2p_landmarks[l])
    std_mean = np.std(p2p_landmarks[l],ddof =1)*(len(p2p_landmarks[l]))**-0.5
    median = np.median(p2p_landmarks[l])
    outliers_perc = outliers_landmarks[l].sum()/len(p2p_landmarks[l]) * 100
    print('    mean point to point error is ' + str(mean) + '+/-' + str(std_mean))
    print('    median point to point error is ' + str(median))
    print('    percentage of images which were outliers is ' + str(outliers_perc) + '%')
    print('    sigma is ' + str(sigmas[l]))
    print('\n')

# %%
# train model functions & paths

import torch
import torch.optim as optim
from torch.optim import lr_scheduler
import time
import copy
import math

# not general

# Paths load and save

PATH_load = r'C:\Users\olive\OneDrive\Documents\CNN\Report\3d_model_unet_crop_32features.pt'
PATH_opt_load = r'C:\Users\olive\OneDrive\Documents\CNN\Report\3d_model_unet_crop_opt_32features.pt'
PATH_sigma_load = r'C:\Users\olive\OneDrive\Documents\CNN\Report\3d_model_unet_crop_sigma_32features.pt'
PATH_scaler_load = r'C:\Users\olive\OneDrive\Documents\CNN\Report\3d_model_unet_crop_scaler_32features.pt'
PATH_val_loss_load = r'C:\Users\olive\OneDrive\Documents\CNN\Report\3d_model_unet_crop_val_loss_32features.pt'


PATH_save = r'C:\Users\olive\OneDrive\Documents\CNN\Report\3d_model_unet_crop_32features.pt'
PATH_opt_save = r'C:\Users\olive\OneDrive\Documents\CNN\Report\3d_model_unet_crop_opt_32features.pt'
PATH_sigma_save = r'C:\Users\olive\OneDrive\Documents\CNN\Report\3d_model_unet_crop_sigma_32features.pt'
PATH_scaler_save = r'C:\Users\olive\OneDrive\Documents\CNN\Report\3d_model_unet_crop_scaler_32features.pt'
PATH_val_loss_save = r'C:\Users\olive\OneDrive\Documents\CNN\Report\3d_model_unet_crop_val_loss_32features.pt'

# %%
# initialise model

model = Unet3d(1,num_class, unet_feat)
model = model.to(device)
# initialise weights

# initialise optimizer/scheduler/scaler
optimizer = optim.Adam([
                {'params': model.parameters()},
                {'params': sigmas[3]},
                #{'params': sigmas[3]} # not general
            ], lr=1e-3, weight_decay = 0.05) # use adam lr optimiser
scheduler = lr_scheduler.StepLR(optimizer, step_size=20000, gamma=0.1)
scaler = torch.cuda.amp.GradScaler(enabled=use_amp)

# %%
# load in a model

# load in sigmas - not specific
for k in landmarks:
  sigmas[k] = torch.load(PATH_sigma_load)['sigma_%1.0f' % k] # what value to initialise sigma


# load in model/optimizer/scaler
model_load = Unet3d(1,num_class,unet_feat)
model_load = model_load.to(device)
optimizer_load = optim.Adam([
                {'params': model.parameters()},
                {'params': sigmas[3]} # not general
            ], lr=1e-3, weight_decay = 0.05) # use adam lr optimiser
scaler_load = torch.cuda.amp.GradScaler()

model_load.load_state_dict(torch.load(PATH_load))
optimizer_load.load_state_dict(torch.load(PATH_opt_load))
scaler_load.load_state_dict(torch.load(PATH_scaler_load))
scheduler = lr_scheduler.StepLR(optimizer_load, step_size=20000, gamma=0.1)

# %%
# Out:
# 1618.7795678937866

# %%
# train initialised model

best_loss = 1e10
train_set.dataset.__train__() 
model, best_loss = train_model(model, scaler, optimizer, scheduler, alpha,reg,gamma,sigmas, num_epochs=epoch_num, best_loss = best_loss)
# Out:
# Epoch 0/149
# ----------
# LR 0.001
# LR 0.001
# C:\Users\olive\anaconda3\lib\site-packages\torch\optim\lr_scheduler.py:131: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (59.42,37.74,57.08)
# pred: (49.00,112.00,69.00)
# point to point
# tensor(75.9249, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(231844.4572, device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 103289.323115, (3, 'sum loss'): 103287.421619, (3, 'reg loss'): 1.885510, (3, 'alpha loss'): 0.016027, (3, 'mean x pred'): 65.264706, (3, 'mean y pred'): 68.426471, (3, 'mean z pred'): 49.323529, (3, 'mean x targ'): 62.469016, (3, 'mean y targ'): 46.452683, (3, 'mean z targ'): 59.946508, (3, 'mean point to point'): 71.900285
# Sigmas are
# Parameter containing:
# tensor([20.0486], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (64.43,46.69,71.14)
# pred: (29.00,108.00,78.00)
# point to point
# tensor(71.1388, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(17704.9872, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 16454.632160, (3, 'sum loss'): 16452.659353, (3, 'reg loss'): 1.956729, (3, 'alpha loss'): 0.016078, (3, 'mean x pred'): 80.000000, (3, 'mean y pred'): 72.625000, (3, 'mean z pred'): 35.000000, (3, 'mean x targ'): 64.006833, (3, 'mean y targ'): 52.764017, (3, 'mean z targ'): 63.015170, (3, 'mean point to point'): 60.228669
# Sigmas are
# Parameter containing:
# tensor([20.0486], device='cuda:0', requires_grad=True)
# saving best model
# 0m 54s
# Estimated finish time:  Fri Jan  1 22:04:17 2021
# Epoch 1/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (65.54,64.35,68.65)
# pred: (121.00,46.00,28.00)
# point to point
# tensor(71.1700, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(15990.2497, device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 10102.562331, (3, 'sum loss'): 10100.502428, (3, 'reg loss'): 2.043786, (3, 'alpha loss'): 0.016122, (3, 'mean x pred'): 71.014706, (3, 'mean y pred'): 55.352941, (3, 'mean z pred'): 56.176471, (3, 'mean x targ'): 61.018288, (3, 'mean y targ'): 46.684613, (3, 'mean z targ'): 60.108535, (3, 'mean point to point'): 50.144397
# Sigmas are
# Parameter containing:
# tensor([20.0969], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (56.14,51.94,72.61)
# pred: (50.00,39.00,47.00)
# point to point
# tensor(29.3410, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(7135.6204, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 9341.166420, (3, 'sum loss'): 9339.008246, (3, 'reg loss'): 2.142018, (3, 'alpha loss'): 0.016155, (3, 'mean x pred'): 57.750000, (3, 'mean y pred'): 38.625000, (3, 'mean z pred'): 39.000000, (3, 'mean x targ'): 62.561698, (3, 'mean y targ'): 53.118690, (3, 'mean z targ'): 62.422168, (3, 'mean point to point'): 42.813114
# Sigmas are
# Parameter containing:
# tensor([20.0969], device='cuda:0', requires_grad=True)
# saving best model
# 0m 53s
# Estimated finish time:  Fri Jan  1 22:01:34 2021
# Epoch 2/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (55.93,52.84,69.65)
# pred: (59.00,62.00,65.00)
# point to point
# tensor(10.7162, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(4756.7618, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 5200.221598, (3, 'sum loss'): 5198.012342, (3, 'reg loss'): 2.193092, (3, 'alpha loss'): 0.016178, (3, 'mean x pred'): 61.926471, (3, 'mean y pred'): 46.470588, (3, 'mean z pred'): 60.779412, (3, 'mean x targ'): 60.047615, (3, 'mean y targ'): 46.743308, (3, 'mean z targ'): 60.047501, (3, 'mean point to point'): 15.417191
# Sigmas are
# Parameter containing:
# tensor([20.1241], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (61.19,45.76,63.56)
# pred: (61.00,45.00,58.00)
# point to point
# tensor(5.6134, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(8972.2992, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 9282.067986, (3, 'sum loss'): 9279.821180, (3, 'reg loss'): 2.230606, (3, 'alpha loss'): 0.016199, (3, 'mean x pred'): 73.500000, (3, 'mean y pred'): 48.375000, (3, 'mean z pred'): 51.875000, (3, 'mean x targ'): 64.486510, (3, 'mean y targ'): 53.120471, (3, 'mean z targ'): 63.194533, (3, 'mean point to point'): 22.802102
# Sigmas are
# Parameter containing:
# tensor([20.1241], device='cuda:0', requires_grad=True)
# saving best model
# 0m 52s
# Estimated finish time:  Fri Jan  1 21:59:32 2021
# Epoch 3/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (61.75,55.57,68.17)
# pred: (65.00,55.00,62.00)
# point to point
# tensor(6.9971, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(2742.3246, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 3715.029677, (3, 'sum loss'): 3712.748328, (3, 'reg loss'): 2.265153, (3, 'alpha loss'): 0.016218, (3, 'mean x pred'): 61.926471, (3, 'mean y pred'): 48.250000, (3, 'mean z pred'): 62.264706, (3, 'mean x targ'): 62.028312, (3, 'mean y targ'): 46.592628, (3, 'mean z targ'): 60.227216, (3, 'mean point to point'): 11.404996
# Sigmas are
# Parameter containing:
# tensor([20.1468], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (60.30,44.27,57.13)
# pred: (14.00,48.00,56.00)
# point to point
# tensor(46.4674, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(16549.2161, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 8730.548614, (3, 'sum loss'): 8728.237834, (3, 'reg loss'): 2.294545, (3, 'alpha loss'): 0.016236, (3, 'mean x pred'): 65.250000, (3, 'mean y pred'): 52.125000, (3, 'mean z pred'): 61.375000, (3, 'mean x targ'): 63.499783, (3, 'mean y targ'): 52.601950, (3, 'mean z targ'): 62.852973, (3, 'mean point to point'): 18.111035
# Sigmas are
# Parameter containing:
# tensor([20.1468], device='cuda:0', requires_grad=True)
# saving best model
# 0m 51s
# Estimated finish time:  Fri Jan  1 21:58:43 2021
# Epoch 4/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (62.45,61.14,60.74)
# pred: (63.00,62.00,65.00)
# point to point
# tensor(4.3762, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(1707.4630, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  0.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  0.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 3119.037108, (3, 'sum loss'): 3116.696587, (3, 'reg loss'): 2.324273, (3, 'alpha loss'): 0.016260, (3, 'mean x pred'): 63.338235, (3, 'mean y pred'): 49.279412, (3, 'mean z pred'): 61.073529, (3, 'mean x targ'): 62.498935, (3, 'mean y targ'): 46.463814, (3, 'mean z targ'): 60.108213, (3, 'mean point to point'): 10.341987
# Sigmas are
# Parameter containing:
# tensor([20.1742], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (66.73,27.60,62.68)
# pred: (40.00,31.00,61.00)
# point to point
# tensor(27.0015, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(15712.5226, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 7789.928069, (3, 'sum loss'): 7787.556943, (3, 'reg loss'): 2.354846, (3, 'alpha loss'): 0.016280, (3, 'mean x pred'): 62.250000, (3, 'mean y pred'): 43.250000, (3, 'mean z pred'): 61.000000, (3, 'mean x targ'): 63.193934, (3, 'mean y targ'): 52.645726, (3, 'mean z targ'): 62.727831, (3, 'mean point to point'): 19.116279
# Sigmas are
# Parameter containing:
# tensor([20.1742], device='cuda:0', requires_grad=True)
# saving best model
# 0m 51s
# Estimated finish time:  Fri Jan  1 21:58:01 2021
# Epoch 5/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (64.27,37.42,57.06)
# pred: (63.00,43.00,58.00)
# point to point
# tensor(5.7986, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(1604.5993, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  0.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  0.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 2843.231813, (3, 'sum loss'): 2840.840185, (3, 'reg loss'): 2.375319, (3, 'alpha loss'): 0.016297, (3, 'mean x pred'): 63.235294, (3, 'mean y pred'): 49.485294, (3, 'mean z pred'): 61.544118, (3, 'mean x targ'): 62.984485, (3, 'mean y targ'): 46.650807, (3, 'mean z targ'): 60.214876, (3, 'mean point to point'): 10.268216
# Sigmas are
# Parameter containing:
# tensor([20.1989], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (65.08,43.01,68.93)
# pred: (64.00,46.00,65.00)
# point to point
# tensor(5.0534, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(2682.1059, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 12850.826916, (3, 'sum loss'): 12848.409748, (3, 'reg loss'): 2.400849, (3, 'alpha loss'): 0.016320, (3, 'mean x pred'): 81.375000, (3, 'mean y pred'): 37.500000, (3, 'mean z pred'): 59.500000, (3, 'mean x targ'): 62.862646, (3, 'mean y targ'): 53.318564, (3, 'mean z targ'): 63.240949, (3, 'mean point to point'): 34.349563
# Sigmas are
# Parameter containing:
# tensor([20.1989], device='cuda:0', requires_grad=True)
# 0m 52s
# Estimated finish time:  Fri Jan  1 22:00:57 2021
# Epoch 6/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (63.55,42.05,66.14)
# pred: (64.00,46.00,65.00)
# point to point
# tensor(4.1367, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(1438.6074, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 2487.260492, (3, 'sum loss'): 2484.820015, (3, 'reg loss'): 2.424139, (3, 'alpha loss'): 0.016337, (3, 'mean x pred'): 63.852941, (3, 'mean y pred'): 49.691176, (3, 'mean z pred'): 61.117647, (3, 'mean x targ'): 62.112537, (3, 'mean y targ'): 46.843799, (3, 'mean z targ'): 60.187837, (3, 'mean point to point'): 10.741785
# Sigmas are
# Parameter containing:
# tensor([20.2224], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (65.62,64.21,64.21)
# pred: (63.00,63.00,64.00)
# point to point
# tensor(2.8896, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(2160.4529, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 13514.180701, (3, 'sum loss'): 13511.717205, (3, 'reg loss'): 2.447138, (3, 'alpha loss'): 0.016358, (3, 'mean x pred'): 67.500000, (3, 'mean y pred'): 53.000000, (3, 'mean z pred'): 54.625000, (3, 'mean x targ'): 63.467054, (3, 'mean y targ'): 53.308104, (3, 'mean z targ'): 63.564275, (3, 'mean point to point'): 18.106320
# Sigmas are
# Parameter containing:
# tensor([20.2224], device='cuda:0', requires_grad=True)
# 0m 53s
# Estimated finish time:  Fri Jan  1 22:01:20 2021
# Epoch 7/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (62.15,54.40,61.36)
# pred: (63.00,53.00,64.00)
# point to point
# tensor(3.1111, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(1490.6518, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 2291.494231, (3, 'sum loss'): 2289.003886, (3, 'reg loss'): 2.473972, (3, 'alpha loss'): 0.016378, (3, 'mean x pred'): 63.455882, (3, 'mean y pred'): 49.220588, (3, 'mean z pred'): 61.544118, (3, 'mean x targ'): 62.092298, (3, 'mean y targ'): 46.773381, (3, 'mean z targ'): 60.349331, (3, 'mean point to point'): 9.681515
# Sigmas are
# Parameter containing:
# tensor([20.2477], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (61.14,65.13,65.85)
# pred: (84.00,60.00,62.00)
# point to point
# tensor(23.7462, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(16667.1407, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 12562.979647, (3, 'sum loss'): 12560.461211, (3, 'reg loss'): 2.502037, (3, 'alpha loss'): 0.016399, (3, 'mean x pred'): 81.500000, (3, 'mean y pred'): 62.000000, (3, 'mean z pred'): 52.000000, (3, 'mean x targ'): 61.937322, (3, 'mean y targ'): 53.043481, (3, 'mean z targ'): 63.086798, (3, 'mean point to point'): 31.450938
# Sigmas are
# Parameter containing:
# tensor([20.2477], device='cuda:0', requires_grad=True)
# 0m 51s
# Estimated finish time:  Fri Jan  1 21:58:23 2021
# Epoch 8/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (55.28,23.68,60.78)
# pred: (61.00,27.00,56.00)
# point to point
# tensor(8.1625, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(1203.5552, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 2199.868511, (3, 'sum loss'): 2197.333722, (3, 'reg loss'): 2.518371, (3, 'alpha loss'): 0.016419, (3, 'mean x pred'): 63.485294, (3, 'mean y pred'): 48.676471, (3, 'mean z pred'): 60.955882, (3, 'mean x targ'): 61.181433, (3, 'mean y targ'): 46.462999, (3, 'mean z targ'): 60.119166, (3, 'mean point to point'): 9.428302
# Sigmas are
# Parameter containing:
# tensor([20.2726], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (68.36,69.70,64.79)
# pred: (47.00,65.00,64.00)
# point to point
# tensor(21.8881, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(16658.6288, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 10037.417036, (3, 'sum loss'): 10034.867026, (3, 'reg loss'): 2.533572, (3, 'alpha loss'): 0.016439, (3, 'mean x pred'): 63.250000, (3, 'mean y pred'): 44.875000, (3, 'mean z pred'): 52.375000, (3, 'mean x targ'): 62.666608, (3, 'mean y targ'): 53.485264, (3, 'mean z targ'): 62.970919, (3, 'mean point to point'): 27.245779
# Sigmas are
# Parameter containing:
# tensor([20.2726], device='cuda:0', requires_grad=True)
# 0m 51s
# Estimated finish time:  Fri Jan  1 21:56:41 2021
# Epoch 9/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (58.11,58.56,67.22)
# pred: (64.00,60.00,63.00)
# point to point
# tensor(7.3916, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(763.6141, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 1934.300981, (3, 'sum loss'): 1931.735456, (3, 'reg loss'): 2.549072, (3, 'alpha loss'): 0.016454, (3, 'mean x pred'): 63.352941, (3, 'mean y pred'): 48.794118, (3, 'mean z pred'): 60.926471, (3, 'mean x targ'): 61.511317, (3, 'mean y targ'): 46.751111, (3, 'mean z targ'): 60.165318, (3, 'mean point to point'): 8.778579
# Sigmas are
# Parameter containing:
# tensor([20.2919], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (63.26,69.18,58.19)
# pred: (64.00,62.00,55.00)
# point to point
# tensor(7.8931, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(13489.3953, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 13254.895755, (3, 'sum loss'): 13252.312624, (3, 'reg loss'): 2.566661, (3, 'alpha loss'): 0.016470, (3, 'mean x pred'): 55.875000, (3, 'mean y pred'): 56.125000, (3, 'mean z pred'): 49.625000, (3, 'mean x targ'): 62.399063, (3, 'mean y targ'): 53.844885, (3, 'mean z targ'): 63.169727, (3, 'mean point to point'): 32.166860
# Sigmas are
# Parameter containing:
# tensor([20.2919], device='cuda:0', requires_grad=True)
# 0m 52s
# Estimated finish time:  Fri Jan  1 22:00:38 2021
# Epoch 10/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (69.03,56.04,59.34)
# pred: (67.00,52.00,60.00)
# point to point
# tensor(4.5719, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(1407.9069, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 1826.213900, (3, 'sum loss'): 1823.607494, (3, 'reg loss'): 2.589916, (3, 'alpha loss'): 0.016491, (3, 'mean x pred'): 63.382353, (3, 'mean y pred'): 49.000000, (3, 'mean z pred'): 61.838235, (3, 'mean x targ'): 62.079729, (3, 'mean y targ'): 46.846069, (3, 'mean z targ'): 60.374264, (3, 'mean point to point'): 8.549791
# Sigmas are
# Parameter containing:
# tensor([20.3178], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (66.22,65.21,64.29)
# pred: (64.00,62.00,67.00)
# point to point
# tensor(4.7493, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(4818.1876, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 15263.176665, (3, 'sum loss'): 15260.543949, (3, 'reg loss'): 2.616203, (3, 'alpha loss'): 0.016512, (3, 'mean x pred'): 57.500000, (3, 'mean y pred'): 49.375000, (3, 'mean z pred'): 58.375000, (3, 'mean x targ'): 65.563972, (3, 'mean y targ'): 54.286572, (3, 'mean z targ'): 63.310413, (3, 'mean point to point'): 32.584170
# Sigmas are
# Parameter containing:
# tensor([20.3178], device='cuda:0', requires_grad=True)
# 0m 53s
# Estimated finish time:  Fri Jan  1 22:02:44 2021
# Epoch 11/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (64.61,40.01,54.88)
# pred: (64.00,44.00,61.00)
# point to point
# tensor(7.3304, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(2313.8986, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  0.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  0.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 1897.313898, (3, 'sum loss'): 1894.653090, (3, 'reg loss'): 2.644270, (3, 'alpha loss'): 0.016537, (3, 'mean x pred'): 64.500000, (3, 'mean y pred'): 49.338235, (3, 'mean z pred'): 61.147059, (3, 'mean x targ'): 62.771860, (3, 'mean y targ'): 46.798527, (3, 'mean z targ'): 60.145909, (3, 'mean point to point'): 9.350749
# Sigmas are
# Parameter containing:
# tensor([20.3472], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (64.96,65.12,65.90)
# pred: (102.00,17.00,67.00)
# point to point
# tensor(60.7316, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(15286.4431, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 7312.568128, (3, 'sum loss'): 7309.884496, (3, 'reg loss'): 2.667072, (3, 'alpha loss'): 0.016560, (3, 'mean x pred'): 70.625000, (3, 'mean y pred'): 49.000000, (3, 'mean z pred'): 54.750000, (3, 'mean x targ'): 63.729095, (3, 'mean y targ'): 53.277910, (3, 'mean z targ'): 63.654238, (3, 'mean point to point'): 27.681164
# Sigmas are
# Parameter containing:
# tensor([20.3472], device='cuda:0', requires_grad=True)
# saving best model
# 0m 51s
# Estimated finish time:  Fri Jan  1 21:58:09 2021
# Epoch 12/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (56.97,62.98,59.89)
# pred: (53.00,68.00,57.00)
# point to point
# tensor(7.0186, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(679.2453, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 1847.625935, (3, 'sum loss'): 1844.920397, (3, 'reg loss'): 2.688967, (3, 'alpha loss'): 0.016582, (3, 'mean x pred'): 63.161765, (3, 'mean y pred'): 48.661765, (3, 'mean z pred'): 61.455882, (3, 'mean x targ'): 60.938885, (3, 'mean y targ'): 46.837245, (3, 'mean z targ'): 60.238137, (3, 'mean point to point'): 9.153051
# Sigmas are
# Parameter containing:
# tensor([20.3749], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (61.63,44.07,57.12)
# pred: (16.00,56.00,50.00)
# point to point
# tensor(47.6947, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(17550.6699, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 13256.754563, (3, 'sum loss'): 13254.023759, (3, 'reg loss'): 2.714199, (3, 'alpha loss'): 0.016606, (3, 'mean x pred'): 68.125000, (3, 'mean y pred'): 58.750000, (3, 'mean z pred'): 59.625000, (3, 'mean x targ'): 62.895956, (3, 'mean y targ'): 52.423082, (3, 'mean z targ'): 62.436359, (3, 'mean point to point'): 24.221139
# Sigmas are
# Parameter containing:
# tensor([20.3749], device='cuda:0', requires_grad=True)
# 0m 51s
# Estimated finish time:  Fri Jan  1 21:57:57 2021
# Epoch 13/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (59.72,36.80,60.12)
# pred: (63.00,43.00,60.00)
# point to point
# tensor(7.0149, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(621.6734, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 1853.947113, (3, 'sum loss'): 1851.195970, (3, 'reg loss'): 2.734518, (3, 'alpha loss'): 0.016625, (3, 'mean x pred'): 62.779412, (3, 'mean y pred'): 48.308824, (3, 'mean z pred'): 61.102941, (3, 'mean x targ'): 60.081084, (3, 'mean y targ'): 46.921483, (3, 'mean z targ'): 60.090688, (3, 'mean point to point'): 8.546385
# Sigmas are
# Parameter containing:
# tensor([20.4009], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (66.95,66.87,58.46)
# pred: (62.00,61.00,56.00)
# point to point
# tensor(8.0634, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(2929.3511, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 7159.578394, (3, 'sum loss'): 7156.808387, (3, 'reg loss'): 2.753359, (3, 'alpha loss'): 0.016648, (3, 'mean x pred'): 62.750000, (3, 'mean y pred'): 51.000000, (3, 'mean z pred'): 48.250000, (3, 'mean x targ'): 64.331743, (3, 'mean y targ'): 51.646489, (3, 'mean z targ'): 62.360518, (3, 'mean point to point'): 18.369496
# Sigmas are
# Parameter containing:
# tensor([20.4009], device='cuda:0', requires_grad=True)
# saving best model
# 0m 51s
# Estimated finish time:  Fri Jan  1 21:57:19 2021
# Epoch 14/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (67.24,34.37,59.90)
# pred: (64.00,31.00,60.00)
# point to point
# tensor(4.6796, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(2844.7846, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 1611.390763, (3, 'sum loss'): 1608.600993, (3, 'reg loss'): 2.773090, (3, 'alpha loss'): 0.016670, (3, 'mean x pred'): 64.205882, (3, 'mean y pred'): 49.191176, (3, 'mean z pred'): 61.294118, (3, 'mean x targ'): 62.521034, (3, 'mean y targ'): 46.677192, (3, 'mean z targ'): 60.171001, (3, 'mean point to point'): 8.480179
# Sigmas are
# Parameter containing:
# tensor([20.4282], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (63.59,64.21,64.31)
# pred: (63.00,64.00,64.00)
# point to point
# tensor(0.6963, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(1596.2596, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 8810.673464, (3, 'sum loss'): 8807.863425, (3, 'reg loss'): 2.793347, (3, 'alpha loss'): 0.016692, (3, 'mean x pred'): 57.750000, (3, 'mean y pred'): 49.500000, (3, 'mean z pred'): 59.875000, (3, 'mean x targ'): 63.023246, (3, 'mean y targ'): 53.348481, (3, 'mean z targ'): 63.295229, (3, 'mean point to point'): 23.524241
# Sigmas are
# Parameter containing:
# tensor([20.4282], device='cuda:0', requires_grad=True)
# 0m 52s
# Estimated finish time:  Fri Jan  1 21:58:57 2021
# Epoch 15/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (56.73,34.76,71.49)
# pred: (63.00,39.00,64.00)
# point to point
# tensor(10.6481, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(1761.8075, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 1507.275490, (3, 'sum loss'): 1504.440859, (3, 'reg loss'): 2.817898, (3, 'alpha loss'): 0.016724, (3, 'mean x pred'): 63.529412, (3, 'mean y pred'): 49.088235, (3, 'mean z pred'): 60.882353, (3, 'mean x targ'): 60.619360, (3, 'mean y targ'): 46.559666, (3, 'mean z targ'): 60.095587, (3, 'mean point to point'): 8.695223
# Sigmas are
# Parameter containing:
# tensor([20.4592], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (61.78,64.21,64.29)
# pred: (63.00,61.00,63.00)
# point to point
# tensor(3.6678, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(1042.7412, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 7256.683806, (3, 'sum loss'): 7253.825577, (3, 'reg loss'): 2.841486, (3, 'alpha loss'): 0.016743, (3, 'mean x pred'): 68.250000, (3, 'mean y pred'): 45.625000, (3, 'mean z pred'): 53.375000, (3, 'mean x targ'): 61.248478, (3, 'mean y targ'): 52.001225, (3, 'mean z targ'): 63.083260, (3, 'mean point to point'): 24.260699
# Sigmas are
# Parameter containing:
# tensor([20.4592], device='cuda:0', requires_grad=True)
# 0m 52s
# Estimated finish time:  Fri Jan  1 21:59:03 2021
# Epoch 16/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (62.94,55.19,58.93)
# pred: (64.00,54.00,59.00)
# point to point
# tensor(1.5952, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(581.7219, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 1599.283718, (3, 'sum loss'): 1596.397223, (3, 'reg loss'): 2.869739, (3, 'alpha loss'): 0.016764, (3, 'mean x pred'): 63.455882, (3, 'mean y pred'): 48.485294, (3, 'mean z pred'): 61.000000, (3, 'mean x targ'): 60.465582, (3, 'mean y targ'): 46.367283, (3, 'mean z targ'): 60.014421, (3, 'mean point to point'): 8.513958
# Sigmas are
# Parameter containing:
# tensor([20.4871], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (65.33,63.88,64.30)
# pred: (64.00,64.00,64.00)
# point to point
# tensor(1.3721, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(7194.0371, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 7644.919448, (3, 'sum loss'): 7642.010287, (3, 'reg loss'): 2.892372, (3, 'alpha loss'): 0.016789, (3, 'mean x pred'): 57.500000, (3, 'mean y pred'): 46.375000, (3, 'mean z pred'): 60.125000, (3, 'mean x targ'): 62.726428, (3, 'mean y targ'): 53.558063, (3, 'mean z targ'): 63.045309, (3, 'mean point to point'): 12.873307
# Sigmas are
# Parameter containing:
# tensor([20.4871], device='cuda:0', requires_grad=True)
# 0m 52s
# Estimated finish time:  Fri Jan  1 22:00:59 2021
# Epoch 17/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (65.41,27.89,67.37)
# pred: (63.00,29.00,64.00)
# point to point
# tensor(4.2867, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(968.8469, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 1519.179208, (3, 'sum loss'): 1516.258441, (3, 'reg loss'): 2.903966, (3, 'alpha loss'): 0.016809, (3, 'mean x pred'): 62.970588, (3, 'mean y pred'): 48.602941, (3, 'mean z pred'): 60.617647, (3, 'mean x targ'): 61.041570, (3, 'mean y targ'): 46.373637, (3, 'mean z targ'): 60.104993, (3, 'mean point to point'): 8.591477
# Sigmas are
# Parameter containing:
# tensor([20.5142], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (63.40,59.47,62.13)
# pred: (65.00,48.00,63.00)
# point to point
# tensor(11.6170, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(9150.2290, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 10415.328082, (3, 'sum loss'): 10412.391198, (3, 'reg loss'): 2.920051, (3, 'alpha loss'): 0.016833, (3, 'mean x pred'): 57.000000, (3, 'mean y pred'): 42.625000, (3, 'mean z pred'): 55.125000, (3, 'mean x targ'): 65.510449, (3, 'mean y targ'): 54.278129, (3, 'mean z targ'): 63.470815, (3, 'mean point to point'): 24.086478
# Sigmas are
# Parameter containing:
# tensor([20.5142], device='cuda:0', requires_grad=True)
# 0m 52s
# Estimated finish time:  Fri Jan  1 21:58:59 2021
# Epoch 18/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (59.64,28.02,67.36)
# pred: (63.00,29.00,64.00)
# point to point
# tensor(4.8544, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(1093.0858, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 1410.441048, (3, 'sum loss'): 1407.480116, (3, 'reg loss'): 2.944075, (3, 'alpha loss'): 0.016850, (3, 'mean x pred'): 63.000000, (3, 'mean y pred'): 48.279412, (3, 'mean z pred'): 60.955882, (3, 'mean x targ'): 61.126327, (3, 'mean y targ'): 46.448155, (3, 'mean z targ'): 60.226419, (3, 'mean point to point'): 7.900023
# Sigmas are
# Parameter containing:
# tensor([20.5389], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (56.58,46.78,70.41)
# pred: (53.00,52.00,67.00)
# point to point
# tensor(7.1877, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(10418.1312, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 18245.105965, (3, 'sum loss'): 18242.118443, (3, 'reg loss'): 2.970649, (3, 'alpha loss'): 0.016874, (3, 'mean x pred'): 55.750000, (3, 'mean y pred'): 60.250000, (3, 'mean z pred'): 49.625000, (3, 'mean x targ'): 63.886917, (3, 'mean y targ'): 52.180386, (3, 'mean z targ'): 62.221924, (3, 'mean point to point'): 26.799456
# Sigmas are
# Parameter containing:
# tensor([20.5389], device='cuda:0', requires_grad=True)
# 0m 51s
# Estimated finish time:  Fri Jan  1 21:56:47 2021
# Epoch 19/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (64.32,38.88,57.39)
# pred: (63.00,43.00,60.00)
# point to point
# tensor(5.0594, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(914.8105, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 1495.156046, (3, 'sum loss'): 1492.136633, (3, 'reg loss'): 3.002516, (3, 'alpha loss'): 0.016898, (3, 'mean x pred'): 63.632353, (3, 'mean y pred'): 48.455882, (3, 'mean z pred'): 60.632353, (3, 'mean x targ'): 61.262466, (3, 'mean y targ'): 46.190907, (3, 'mean z targ'): 59.941229, (3, 'mean point to point'): 8.946427
# Sigmas are
# Parameter containing:
# tensor([20.5707], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (62.81,59.52,62.14)
# pred: (63.00,55.00,64.00)
# point to point
# tensor(4.8943, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(1470.2103, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 7661.036438, (3, 'sum loss'): 7657.968460, (3, 'reg loss'): 3.051052, (3, 'alpha loss'): 0.016926, (3, 'mean x pred'): 64.125000, (3, 'mean y pred'): 52.250000, (3, 'mean z pred'): 53.750000, (3, 'mean x targ'): 63.695756, (3, 'mean y targ'): 52.259854, (3, 'mean z targ'): 62.948893, (3, 'mean point to point'): 20.664319
# Sigmas are
# Parameter containing:
# tensor([20.5707], device='cuda:0', requires_grad=True)
# 0m 52s
# Estimated finish time:  Fri Jan  1 21:59:44 2021
# Epoch 20/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (58.74,64.88,60.58)
# pred: (64.00,64.00,57.00)
# point to point
# tensor(6.4225, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(562.3973, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 1391.330958, (3, 'sum loss'): 1388.232717, (3, 'reg loss'): 3.081287, (3, 'alpha loss'): 0.016952, (3, 'mean x pred'): 62.514706, (3, 'mean y pred'): 48.705882, (3, 'mean z pred'): 61.029412, (3, 'mean x targ'): 61.258806, (3, 'mean y targ'): 46.563477, (3, 'mean z targ'): 60.144244, (3, 'mean point to point'): 7.627307
# Sigmas are
# Parameter containing:
# tensor([20.6000], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (65.98,45.01,58.02)
# pred: (35.00,90.00, 7.00)
# point to point
# tensor(74.7476, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(15807.9870, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 7839.034528, (3, 'sum loss'): 7835.911875, (3, 'reg loss'): 3.105679, (3, 'alpha loss'): 0.016974, (3, 'mean x pred'): 63.125000, (3, 'mean y pred'): 59.625000, (3, 'mean z pred'): 48.500000, (3, 'mean x targ'): 65.273163, (3, 'mean y targ'): 53.450921, (3, 'mean z targ'): 63.167401, (3, 'mean point to point'): 29.553658
# Sigmas are
# Parameter containing:
# tensor([20.6000], device='cuda:0', requires_grad=True)
# 0m 50s
# Estimated finish time:  Fri Jan  1 21:56:31 2021
# Epoch 21/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (55.59,56.23,57.30)
# pred: (58.00,55.00,56.00)
# point to point
# tensor(3.0010, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(804.8189, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 1364.717964, (3, 'sum loss'): 1361.581837, (3, 'reg loss'): 3.119135, (3, 'alpha loss'): 0.016992, (3, 'mean x pred'): 64.235294, (3, 'mean y pred'): 48.632353, (3, 'mean z pred'): 61.073529, (3, 'mean x targ'): 61.933430, (3, 'mean y targ'): 46.566986, (3, 'mean z targ'): 60.226489, (3, 'mean point to point'): 8.360277
# Sigmas are
# Parameter containing:
# tensor([20.6241], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (67.82,27.64,62.67)
# pred: (38.00,32.00,57.00)
# point to point
# tensor(30.6669, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(15167.7819, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 7905.177331, (3, 'sum loss'): 7902.020101, (3, 'reg loss'): 3.140217, (3, 'alpha loss'): 0.017014, (3, 'mean x pred'): 56.375000, (3, 'mean y pred'): 48.000000, (3, 'mean z pred'): 51.875000, (3, 'mean x targ'): 65.325973, (3, 'mean y targ'): 53.272032, (3, 'mean z targ'): 63.044605, (3, 'mean point to point'): 19.086947
# Sigmas are
# Parameter containing:
# tensor([20.6241], device='cuda:0', requires_grad=True)
# 0m 51s
# Estimated finish time:  Fri Jan  1 21:57:36 2021
# Epoch 22/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (61.74,38.70,52.73)
# pred: (64.00,33.00,56.00)
# point to point
# tensor(6.9484, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(1870.2124, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 1363.629292, (3, 'sum loss'): 1360.454432, (3, 'reg loss'): 3.157818, (3, 'alpha loss'): 0.017037, (3, 'mean x pred'): 63.705882, (3, 'mean y pred'): 48.558824, (3, 'mean z pred'): 61.088235, (3, 'mean x targ'): 61.401015, (3, 'mean y targ'): 46.717685, (3, 'mean z targ'): 60.258283, (3, 'mean point to point'): 8.101799
# Sigmas are
# Parameter containing:
# tensor([20.6532], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (65.30,63.96,64.30)
# pred: (65.00,63.00,78.00)
# point to point
# tensor(13.7369, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(12170.6813, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 11387.946205, (3, 'sum loss'): 11384.753882, (3, 'reg loss'): 3.175261, (3, 'alpha loss'): 0.017062, (3, 'mean x pred'): 47.625000, (3, 'mean y pred'): 54.750000, (3, 'mean z pred'): 51.000000, (3, 'mean x targ'): 65.611382, (3, 'mean y targ'): 52.162558, (3, 'mean z targ'): 62.897041, (3, 'mean point to point'): 31.143914
# Sigmas are
# Parameter containing:
# tensor([20.6532], device='cuda:0', requires_grad=True)
# 0m 51s
# Estimated finish time:  Fri Jan  1 21:58:36 2021
# Epoch 23/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (54.34,78.68,74.47)
# pred: (54.00,79.00,72.00)
# point to point
# tensor(2.5106, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(1170.6794, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 1288.289544, (3, 'sum loss'): 1285.074253, (3, 'reg loss'): 3.198207, (3, 'alpha loss'): 0.017082, (3, 'mean x pred'): 62.514706, (3, 'mean y pred'): 49.441176, (3, 'mean z pred'): 61.220588, (3, 'mean x targ'): 61.603544, (3, 'mean y targ'): 46.734882, (3, 'mean z targ'): 60.260728, (3, 'mean point to point'): 7.846018
# Sigmas are
# Parameter containing:
# tensor([20.6773], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (67.44,46.39,59.07)
# pred: (62.00,31.00, 8.00)
# point to point
# tensor(53.6103, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(15586.7410, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 9592.678128, (3, 'sum loss'): 9589.433410, (3, 'reg loss'): 3.227616, (3, 'alpha loss'): 0.017102, (3, 'mean x pred'): 59.125000, (3, 'mean y pred'): 50.875000, (3, 'mean z pred'): 43.500000, (3, 'mean x targ'): 64.655623, (3, 'mean y targ'): 53.803511, (3, 'mean z targ'): 63.004005, (3, 'mean point to point'): 23.577049
# Sigmas are
# Parameter containing:
# tensor([20.6773], device='cuda:0', requires_grad=True)
# 0m 53s
# Estimated finish time:  Fri Jan  1 22:01:15 2021
# Epoch 24/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (61.44,63.47,57.43)
# pred: (63.00,64.00,54.00)
# point to point
# tensor(3.8026, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(1184.8714, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 1300.370576, (3, 'sum loss'): 1297.084524, (3, 'reg loss'): 3.268919, (3, 'alpha loss'): 0.017136, (3, 'mean x pred'): 63.735294, (3, 'mean y pred'): 49.426471, (3, 'mean z pred'): 60.955882, (3, 'mean x targ'): 60.827375, (3, 'mean y targ'): 46.789097, (3, 'mean z targ'): 60.082098, (3, 'mean point to point'): 8.364982
# Sigmas are
# Parameter containing:
# tensor([20.7145], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (65.26,64.02,64.29)
# pred: (55.00,27.00,42.00)
# point to point
# tensor(44.4153, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(13002.2814, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 8424.947842, (3, 'sum loss'): 8421.634517, (3, 'reg loss'): 3.296161, (3, 'alpha loss'): 0.017164, (3, 'mean x pred'): 57.625000, (3, 'mean y pred'): 46.625000, (3, 'mean z pred'): 50.250000, (3, 'mean x targ'): 63.754937, (3, 'mean y targ'): 53.430831, (3, 'mean z targ'): 62.630984, (3, 'mean point to point'): 28.120178
# Sigmas are
# Parameter containing:
# ...
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (65.75,59.53,62.05)
# pred: (63.00,51.00,59.00)
# point to point
# tensor(9.4675, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(1618.7653, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 5671.137573, (3, 'sum loss'): 5663.192689, (3, 'reg loss'): 7.923006, (3, 'alpha loss'): 0.021877, (3, 'mean x pred'): 60.625000, (3, 'mean y pred'): 58.875000, (3, 'mean z pred'): 56.000000, (3, 'mean x targ'): 62.580342, (3, 'mean y targ'): 52.356829, (3, 'mean z targ'): 62.852145, (3, 'mean point to point'): 17.702240
# Sigmas are
# Parameter containing:
# tensor([23.3865], device='cuda:0', requires_grad=True)
# 0m 48s
# Estimated finish time:  Fri Jan  1 21:55:02 2021
# Epoch 142/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (67.92,47.11,62.72)
# pred: (63.00,45.00,63.00)
# point to point
# tensor(5.3624, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(124.9822, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 174.474022, (3, 'sum loss'): 166.531736, (3, 'reg loss'): 7.920397, (3, 'alpha loss'): 0.021888, (3, 'mean x pred'): 64.235294, (3, 'mean y pred'): 47.676471, (3, 'mean z pred'): 62.073529, (3, 'mean x targ'): 62.078509, (3, 'mean y targ'): 46.507508, (3, 'mean z targ'): 60.036185, (3, 'mean point to point'): 6.897860
# Sigmas are
# Parameter containing:
# tensor([23.3986], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (64.14,44.03,69.65)
# pred: (102.00,62.00,56.00)
# point to point
# tensor(44.0792, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(8192.5972, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 5264.803343, (3, 'sum loss'): 5256.863110, (3, 'reg loss'): 7.918333, (3, 'alpha loss'): 0.021900, (3, 'mean x pred'): 67.000000, (3, 'mean y pred'): 54.000000, (3, 'mean z pred'): 61.250000, (3, 'mean x targ'): 64.810119, (3, 'mean y targ'): 52.157327, (3, 'mean z targ'): 63.008928, (3, 'mean point to point'): 22.616321
# Sigmas are
# Parameter containing:
# tensor([23.3986], device='cuda:0', requires_grad=True)
# 0m 49s
# Estimated finish time:  Fri Jan  1 21:55:03 2021
# Epoch 143/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (61.93,15.61,48.81)
# pred: (63.00,16.00,51.00)
# point to point
# tensor(2.4673, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(280.7471, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  0.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  0.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 157.379522, (3, 'sum loss'): 149.438914, (3, 'reg loss'): 7.918696, (3, 'alpha loss'): 0.021912, (3, 'mean x pred'): 62.367647, (3, 'mean y pred'): 49.779412, (3, 'mean z pred'): 62.176471, (3, 'mean x targ'): 62.713260, (3, 'mean y targ'): 46.871657, (3, 'mean z targ'): 60.232385, (3, 'mean point to point'): 5.925579
# Sigmas are
# Parameter containing:
# tensor([23.4112], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (60.96,44.16,57.13)
# pred: (23.00,96.00,62.00)
# point to point
# tensor(64.4400, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(10260.7649, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 8025.431947, (3, 'sum loss'): 8017.493012, (3, 'reg loss'): 7.917012, (3, 'alpha loss'): 0.021923, (3, 'mean x pred'): 63.375000, (3, 'mean y pred'): 64.625000, (3, 'mean z pred'): 62.125000, (3, 'mean x targ'): 64.231634, (3, 'mean y targ'): 52.939433, (3, 'mean z targ'): 63.217602, (3, 'mean point to point'): 23.002213
# Sigmas are
# Parameter containing:
# tensor([23.4112], device='cuda:0', requires_grad=True)
# 0m 48s
# Estimated finish time:  Fri Jan  1 21:55:02 2021
# Epoch 144/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (65.71,66.03,55.86)
# pred: (64.00,63.00,55.00)
# point to point
# tensor(3.5846, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(151.3171, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 168.082713, (3, 'sum loss'): 160.147416, (3, 'reg loss'): 7.913364, (3, 'alpha loss'): 0.021933, (3, 'mean x pred'): 61.985294, (3, 'mean y pred'): 48.147059, (3, 'mean z pred'): 62.441176, (3, 'mean x targ'): 60.770550, (3, 'mean y targ'): 46.441282, (3, 'mean z targ'): 59.970319, (3, 'mean point to point'): 6.506352
# Sigmas are
# Parameter containing:
# tensor([23.4224], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (60.47,69.18,57.96)
# pred: (62.00,68.00,57.00)
# point to point
# tensor(2.1586, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(6963.9576, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 6003.522497, (3, 'sum loss'): 5995.588518, (3, 'reg loss'): 7.912035, (3, 'alpha loss'): 0.021944, (3, 'mean x pred'): 65.500000, (3, 'mean y pred'): 61.125000, (3, 'mean z pred'): 56.125000, (3, 'mean x targ'): 63.943700, (3, 'mean y targ'): 52.772362, (3, 'mean z targ'): 63.101552, (3, 'mean point to point'): 16.000674
# Sigmas are
# Parameter containing:
# tensor([23.4224], device='cuda:0', requires_grad=True)
# 0m 48s
# Estimated finish time:  Fri Jan  1 21:55:01 2021
# Epoch 145/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (65.57,45.83,58.87)
# pred: (68.00,48.00,57.00)
# point to point
# tensor(3.7562, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(129.4700, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 164.426306, (3, 'sum loss'): 156.495375, (3, 'reg loss'): 7.908978, (3, 'alpha loss'): 0.021953, (3, 'mean x pred'): 64.691176, (3, 'mean y pred'): 50.014706, (3, 'mean z pred'): 61.735294, (3, 'mean x targ'): 61.277886, (3, 'mean y targ'): 46.705804, (3, 'mean z targ'): 59.934000, (3, 'mean point to point'): 7.897310
# Sigmas are
# Parameter containing:
# tensor([23.4339], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (64.94,69.19,58.16)
# pred: (67.00,65.00,60.00)
# point to point
# tensor(5.0131, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(1891.3838, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 5908.310956, (3, 'sum loss'): 5900.381670, (3, 'reg loss'): 7.907321, (3, 'alpha loss'): 0.021966, (3, 'mean x pred'): 63.000000, (3, 'mean y pred'): 49.875000, (3, 'mean z pred'): 53.375000, (3, 'mean x targ'): 64.064951, (3, 'mean y targ'): 52.632124, (3, 'mean z targ'): 62.988152, (3, 'mean point to point'): 15.956210
# Sigmas are
# Parameter containing:
# tensor([23.4339], device='cuda:0', requires_grad=True)
# 0m 48s
# Estimated finish time:  Fri Jan  1 21:55:00 2021
# Epoch 146/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (65.36,11.76,45.81)
# pred: (68.00,15.00,52.00)
# point to point
# tensor(7.4718, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(1123.8001, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 209.878295, (3, 'sum loss'): 201.943405, (3, 'reg loss'): 7.912904, (3, 'alpha loss'): 0.021986, (3, 'mean x pred'): 63.823529, (3, 'mean y pred'): 48.323529, (3, 'mean z pred'): 62.470588, (3, 'mean x targ'): 61.933771, (3, 'mean y targ'): 46.902892, (3, 'mean z targ'): 60.191082, (3, 'mean point to point'): 6.529885
# Sigmas are
# Parameter containing:
# tensor([23.4501], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (58.59,27.60,62.38)
# pred: (59.00,30.00,36.00)
# point to point
# tensor(26.4888, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(9833.6335, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 5569.541645, (3, 'sum loss'): 5561.601972, (3, 'reg loss'): 7.917677, (3, 'alpha loss'): 0.021996, (3, 'mean x pred'): 60.500000, (3, 'mean y pred'): 54.750000, (3, 'mean z pred'): 53.500000, (3, 'mean x targ'): 63.176518, (3, 'mean y targ'): 52.992217, (3, 'mean z targ'): 63.148341, (3, 'mean point to point'): 12.259328
# Sigmas are
# Parameter containing:
# tensor([23.4501], device='cuda:0', requires_grad=True)
# 0m 49s
# Estimated finish time:  Fri Jan  1 21:55:04 2021
# Epoch 147/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (67.82,49.55,53.89)
# pred: (67.00,48.00,54.00)
# point to point
# tensor(1.7551, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(234.7810, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 271.359135, (3, 'sum loss'): 263.422118, (3, 'reg loss'): 7.915008, (3, 'alpha loss'): 0.022009, (3, 'mean x pred'): 64.088235, (3, 'mean y pred'): 50.617647, (3, 'mean z pred'): 62.323529, (3, 'mean x targ'): 61.313459, (3, 'mean y targ'): 46.833519, (3, 'mean z targ'): 60.270717, (3, 'mean point to point'): 8.056686
# Sigmas are
# Parameter containing:
# tensor([23.4642], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (64.83,49.24,65.93)
# pred: (62.00,20.00,37.00)
# point to point
# tensor(41.2290, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(9630.1050, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 6238.688728, (3, 'sum loss'): 6230.754317, (3, 'reg loss'): 7.912389, (3, 'alpha loss'): 0.022023, (3, 'mean x pred'): 68.750000, (3, 'mean y pred'): 57.750000, (3, 'mean z pred'): 50.625000, (3, 'mean x targ'): 64.115033, (3, 'mean y targ'): 52.920125, (3, 'mean z targ'): 63.408089, (3, 'mean point to point'): 30.318899
# Sigmas are
# Parameter containing:
# tensor([23.4642], device='cuda:0', requires_grad=True)
# 0m 49s
# Estimated finish time:  Fri Jan  1 21:55:03 2021
# Epoch 148/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (60.06,53.68,63.16)
# pred: (59.00,56.00,62.00)
# point to point
# tensor(2.7991, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(187.2055, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 208.290365, (3, 'sum loss'): 200.333843, (3, 'reg loss'): 7.934459, (3, 'alpha loss'): 0.022063, (3, 'mean x pred'): 63.220588, (3, 'mean y pred'): 46.985294, (3, 'mean z pred'): 62.411765, (3, 'mean x targ'): 60.906943, (3, 'mean y targ'): 46.568072, (3, 'mean z targ'): 60.135022, (3, 'mean point to point'): 7.091192
# Sigmas are
# Parameter containing:
# tensor([23.4963], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (64.83,45.74,63.56)
# pred: (67.00,41.00,59.00)
# point to point
# tensor(6.9257, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(647.2781, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 4357.359137, (3, 'sum loss'): 4349.395983, (3, 'reg loss'): 7.941070, (3, 'alpha loss'): 0.022083, (3, 'mean x pred'): 69.625000, (3, 'mean y pred'): 63.250000, (3, 'mean z pred'): 63.500000, (3, 'mean x targ'): 64.283465, (3, 'mean y targ'): 52.665457, (3, 'mean z targ'): 63.137652, (3, 'mean point to point'): 21.415188
# Sigmas are
# Parameter containing:
# tensor([23.4963], device='cuda:0', requires_grad=True)
# saving best model
# 0m 49s
# Estimated finish time:  Fri Jan  1 21:55:04 2021
# Epoch 149/149
# ----------
# LR 0.001
# LR 0.001
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (63.88,42.07,66.15)
# pred: (66.00,43.00,65.00)
# point to point
# tensor(2.5844, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(66.4381, device='cuda:0', dtype=torch.float64, grad_fn=<AddBackward0>)
#  ---- first image of set ---- (end)
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  4.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  0.00
# heatmap minimum value  0.00
# no structure for 3
# heatmap maximum value  0.00
# heatmap minimum value  0.00
# Phase: Landmark, Value
# train: (3, 'loss'): 199.708943, (3, 'sum loss'): 191.747811, (3, 'reg loss'): 7.939038, (3, 'alpha loss'): 0.022095, (3, 'mean x pred'): 60.617647, (3, 'mean y pred'): 48.338235, (3, 'mean z pred'): 62.573529, (3, 'mean x targ'): 60.651565, (3, 'mean y targ'): 46.479721, (3, 'mean z targ'): 60.308024, (3, 'mean point to point'): 6.323212
# Sigmas are
# Parameter containing:
# tensor([23.5102], device='cuda:0', requires_grad=True)
# ------- First image of set --------
# Landmark 3
# --------------
# targ: (58.24,64.20,63.83)
# pred: (55.00,64.00,66.00)
# point to point
# tensor(3.9027, device='cuda:0', dtype=torch.float64)
# img loss
# tensor(299.7448, device='cuda:0', dtype=torch.float64)
#  ---- first image of set ---- (end)
# Phase: Landmark, Value
# val: (3, 'loss'): 7239.846202, (3, 'sum loss'): 7231.883974, (3, 'reg loss'): 7.940119, (3, 'alpha loss'): 0.022109, (3, 'mean x pred'): 62.750000, (3, 'mean y pred'): 68.625000, (3, 'mean z pred'): 59.750000, (3, 'mean x targ'): 63.297532, (3, 'mean y targ'): 52.093642, (3, 'mean z targ'): 62.385052, (3, 'mean point to point'): 28.031373
# Sigmas are
# Parameter containing:
# tensor([23.5102], device='cuda:0', requires_grad=True)
# 0m 48s
# Estimated finish time:  Fri Jan  1 21:55:03 2021
# Best val loss: 4357.359137

# %%
#print('parameters',sigmas[3])
# Out:
# parameters Parameter containing:
# tensor([50.0246], device='cuda:0', requires_grad=True)

# %%
# evaluate initialised model
# !nvidia-smi
model.eval()   # Set model to the evaluation mode
test_set.dataset.__test__() # sets whole dataset to test mode means it doesn't augment images
performance_metrics(model,sigmas,gamma)
# Out:
# Sat Jan 02 00:25:11 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 452.41       Driver Version: 452.41       CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 2060   WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   40C    P8     2W /  N/A |   1634MiB /  6144MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1408    C+G   Insufficient Permissions        N/A      |
# |    0   N/A  N/A      7592      C   ...live\anaconda3\python.exe    N/A      |
# +-----------------------------------------------------------------------------+
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# Structure COM:
# tensor(61.9636, device='cuda:0', dtype=torch.float64) tensor(38.2382, device='cuda:0', dtype=torch.float64) tensor(72.8080, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(62.3604, dtype=torch.float64) tensor(39.6822, dtype=torch.float64) tensor(62.7994, dtype=torch.float64)
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# Structure COM:
# tensor(68.1371, device='cuda:0', dtype=torch.float64) tensor(32.1021, device='cuda:0', dtype=torch.float64) tensor(59.2817, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(77.6041, dtype=torch.float64) tensor(27.9818, dtype=torch.float64) tensor(80., dtype=torch.float64)
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# Structure COM:
# tensor(62.4577, device='cuda:0', dtype=torch.float64) tensor(23.4092, device='cuda:0', dtype=torch.float64) tensor(64.4132, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(60.9547, dtype=torch.float64) tensor(21.6063, dtype=torch.float64) tensor(61.1378, dtype=torch.float64)
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# Structure COM:
# tensor(61.0064, device='cuda:0', dtype=torch.float64) tensor(52.3263, device='cuda:0', dtype=torch.float64) tensor(54.2016, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(60.8481, dtype=torch.float64) tensor(51.4136, dtype=torch.float64) tensor(57.6055, dtype=torch.float64)
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# Structure COM:
# tensor(68.4517, device='cuda:0', dtype=torch.float64) tensor(99.3228, device='cuda:0', dtype=torch.float64) tensor(52.0605, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(69.0077, dtype=torch.float64) tensor(86.5046, dtype=torch.float64) tensor(55.1553, dtype=torch.float64)
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# Structure COM:
# tensor(60.5101, device='cuda:0', dtype=torch.float64) tensor(18.8642, device='cuda:0', dtype=torch.float64) tensor(65.9255, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(60.9718, dtype=torch.float64) tensor(25.3742, dtype=torch.float64) tensor(61.3534, dtype=torch.float64)
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# Structure COM:
# tensor(60.2112, device='cuda:0', dtype=torch.float64) tensor(70.4245, device='cuda:0', dtype=torch.float64) tensor(52.3353, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(59.8247, dtype=torch.float64) tensor(60.4180, dtype=torch.float64) tensor(58.0776, dtype=torch.float64)
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# Structure COM:
# tensor(63.2324, device='cuda:0', dtype=torch.float64) tensor(39.8193, device='cuda:0', dtype=torch.float64) tensor(57.9085, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(79.3418, dtype=torch.float64) tensor(21.0387, dtype=torch.float64) tensor(80., dtype=torch.float64)
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# Structure COM:
# tensor(58.3910, device='cuda:0', dtype=torch.float64) tensor(28.8246, device='cuda:0', dtype=torch.float64) tensor(68.5378, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(55.3707, dtype=torch.float64) tensor(25.0298, dtype=torch.float64) tensor(63.4882, dtype=torch.float64)
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# Structure COM:
# tensor(66.7707, device='cuda:0', dtype=torch.float64) tensor(38.0829, device='cuda:0', dtype=torch.float64) tensor(60.4752, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(83.1571, dtype=torch.float64) tensor(0., dtype=torch.float64) tensor(80., dtype=torch.float64)
#
#
# Landmark 3
#     mean point to point error is 38.17255057261771+/-9.505100620260393
#     median point to point error is 23.121783076107647
#     percentage of images which were outliers is 60.0%
#     sigma is Parameter containing:
# tensor([23.5102], device='cuda:0', requires_grad=True)

# %%
# train loaded in model

# load in val loss
best_loss = torch.load(PATH_val_loss_load)['best_val_loss']

train_set.dataset.__train__() 
model_load, best_loss = train_model(model_load, scaler_load, optimizer_load, scheduler, alpha,reg,gamma,sigmas, num_epochs=epoch_num, best_loss = best_loss)

# %%
# evaluate loaded in model
# !nvidia-smi

best_loss = torch.load(PATH_val_loss_load)['best_val_loss']
print(best_loss)

model_load.eval()
test_set.dataset.__test__() # sets whole dataset to test mode means it doesn't augment images
performance_metrics(model_load,sigmas,gamma)
# Out:
# Mon Jan 04 11:11:17 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 452.41       Driver Version: 452.41       CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 2060   WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   44C    P8     4W /  N/A |   2999MiB /  6144MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1428    C+G   Insufficient Permissions        N/A      |
# |    0   N/A  N/A      8720    C+G   ...ystemEventUtilityHost.exe    N/A      |
# |    0   N/A  N/A     13436    C+G   ...mmandCenterBackground.exe    N/A      |
# |    0   N/A  N/A     14832      C   ...live\anaconda3\python.exe    N/A      |
# |    0   N/A  N/A     16400      C   ...live\anaconda3\python.exe    N/A      |
# +-----------------------------------------------------------------------------+
# 4357.359136819976
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# torch.cuda.FloatTensor
# torch.cuda.FloatTensor
# Structure COM:
# tensor(61.9636, device='cuda:0', dtype=torch.float64) tensor(38.2382, device='cuda:0', dtype=torch.float64) tensor(72.8080, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(62, device='cuda:0') tensor(45, device='cuda:0') tensor(67, device='cuda:0')
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# torch.cuda.FloatTensor
# torch.cuda.FloatTensor
# Structure COM:
# tensor(68.1371, device='cuda:0', dtype=torch.float64) tensor(32.1021, device='cuda:0', dtype=torch.float64) tensor(59.2817, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(46, device='cuda:0') tensor(81, device='cuda:0') tensor(62, device='cuda:0')
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# torch.cuda.FloatTensor
# torch.cuda.FloatTensor
# Structure COM:
# tensor(62.4577, device='cuda:0', dtype=torch.float64) tensor(23.4092, device='cuda:0', dtype=torch.float64) tensor(64.4132, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(60, device='cuda:0') tensor(21, device='cuda:0') tensor(63, device='cuda:0')
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# torch.cuda.FloatTensor
# torch.cuda.FloatTensor
# Structure COM:
# tensor(61.0064, device='cuda:0', dtype=torch.float64) tensor(52.3263, device='cuda:0', dtype=torch.float64) tensor(54.2016, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(60, device='cuda:0') tensor(61, device='cuda:0') tensor(55, device='cuda:0')
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# torch.cuda.FloatTensor
# torch.cuda.FloatTensor
# Structure COM:
# tensor(68.4517, device='cuda:0', dtype=torch.float64) tensor(99.3228, device='cuda:0', dtype=torch.float64) tensor(52.0605, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(70, device='cuda:0') tensor(80, device='cuda:0') tensor(55, device='cuda:0')
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# torch.cuda.FloatTensor
# torch.cuda.FloatTensor
# Structure COM:
# tensor(60.5101, device='cuda:0', dtype=torch.float64) tensor(18.8642, device='cuda:0', dtype=torch.float64) tensor(65.9255, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(58, device='cuda:0') tensor(27, device='cuda:0') tensor(59, device='cuda:0')
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# torch.cuda.FloatTensor
# torch.cuda.FloatTensor
# Structure COM:
# tensor(60.2112, device='cuda:0', dtype=torch.float64) tensor(70.4245, device='cuda:0', dtype=torch.float64) tensor(52.3353, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(59, device='cuda:0') tensor(63, device='cuda:0') tensor(56, device='cuda:0')
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# torch.cuda.FloatTensor
# torch.cuda.FloatTensor
# Structure COM:
# tensor(63.2324, device='cuda:0', dtype=torch.float64) tensor(39.8193, device='cuda:0', dtype=torch.float64) tensor(57.9085, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(23, device='cuda:0') tensor(87, device='cuda:0') tensor(71, device='cuda:0')
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# torch.cuda.FloatTensor
# torch.cuda.FloatTensor
# Structure COM:
# tensor(58.3910, device='cuda:0', dtype=torch.float64) tensor(28.8246, device='cuda:0', dtype=torch.float64) tensor(68.5378, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(55, device='cuda:0') tensor(31, device='cuda:0') tensor(66, device='cuda:0')
# torch.Size([1, 1, 128, 128, 80])
# 3D plots for landmark 3
# torch.cuda.FloatTensor
# torch.cuda.FloatTensor
# Structure COM:
# tensor(66.7707, device='cuda:0', dtype=torch.float64) tensor(38.0829, device='cuda:0', dtype=torch.float64) tensor(60.4752, device='cuda:0', dtype=torch.float64)
# Predicted COM:
# tensor(33, device='cuda:0') tensor(0, device='cuda:0') tensor(79, device='cuda:0')
#
#
# Landmark 3
#     mean point to point error is 38.4089075056011+/-10.888075431208827
#     median point to point error is 24.14510740379261
#     percentage of images which were outliers is 60.0%
#     sigma is Parameter containing:
# tensor([23.5102], device='cuda:0', requires_grad=True)

# %%
# save intialised model to documents

"""
# careful if uncommenting below could overwrite!!!

torch.save(model.state_dict(), PATH_save)
torch.save(optimizer.state_dict(), PATH_opt_save)
torch.save({
            'sigma_3': sigmas[3],
            }, PATH_sigma_save) # change accordingly
torch.save(scaler.state_dict(), PATH_scaler_save)
torch.save({'best_val_loss': best_loss}, PATH_val_loss_save)
"""

# %%
# save loaded in model to documents

# careful if uncommenting below could overwrite!!!

"""
torch.save(model_load.state_dict(), PATH_save)
torch.save(optimizer_load.state_dict(), PATH_opt_save)
torch.save({
            'sigma_3': sigmas[3],
            }, PATH_sigma_save) # change accordingly
torch.save(scaler_load.state_dict(), PATH_scaler_save)
torch.save({'best_val_loss': best_loss}, PATH_val_loss_save)
"""
